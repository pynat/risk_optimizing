# %%
# standard
import time
import logging
import warnings
from datetime import date, datetime, timedelta
warnings.filterwarnings("ignore", category=FutureWarning)

# core data 
import numpy as np
import pandas as pd
import requests

# statistics econometrics
from scipy import stats
from statsmodels.tsa.stattools import adfuller, grangercausalitytests
from statsmodels.stats.stattools import durbin_watson
from statsmodels.stats.diagnostic import acorr_ljungbox
import statsmodels.api as sm

# machine learning
from sklearn.ensemble import RandomForestClassifier
from sklearn.inspection import permutation_importance
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import accuracy_score, log_loss, roc_auc_score, classification_report
from sklearn.preprocessing import label_binarize


from tigramite import data_processing as pp
from tigramite.pcmci import PCMCI
from tigramite.independence_tests.parcorr import ParCorr
import tigramite.plotting as tp


# finance
import talib as ta
from hmmlearn import hmm

# network analysis
import networkx as nx

# visualization
import matplotlib.pyplot as plt
from matplotlib import rcParams
import matplotlib.patches as mpatches
import seaborn as sns

import vectorbt as vbt

# %%
# get eth data 
logging.basicConfig(level=logging.INFO, format="%(asctime)s - %(levelname)s - %(message)s")
SYMBOL   = "ETHUSDT"
INTERVAL = "1h"         
YEARS    = 3
DOLLAR_BAR_THRESHOLD = 500_000_000

def fetch_ohlcv(symbol: str, interval: str, years: int) -> pd.DataFrame:
    url        = "https://api.binance.com/api/v1/klines"
    start_time = datetime.now() - timedelta(days=365 * years)
    end_time   = datetime.now()
    all_data   = []
    chunk_map  = {"1m": 1, "1h": 40, "1d": 90}
    chunk_days = chunk_map.get(interval, 40)
    while start_time < end_time:
        params = {
            "symbol":    symbol,
            "interval":  interval,
            "startTime": int(start_time.timestamp() * 1000),
            "endTime":   int((start_time + timedelta(days=chunk_days)).timestamp() * 1000),
            "limit":     1000,
        }
        r = requests.get(url, params=params)
        if r.status_code != 200:
            logging.error(f"request failed: {r.status_code}")
            break
        data = r.json()
        if not data:
            break
        all_data.extend(data)
        start_time = pd.to_datetime(data[-1][0], unit="ms") + timedelta(milliseconds=1)
        logging.info(f"fetched up to {start_time}")
        time.sleep(0.25)
    cols = ["timestamp","open","high","low","close","volume",
            "close_time","quote_volume","trades",
            "taker_base","taker_quote","ignore"]
    df = pd.DataFrame(all_data, columns=cols)
    df["timestamp"] = pd.to_datetime(df["timestamp"], unit="ms")
    df.set_index("timestamp", inplace=True)
    for col in ["open","high","low","close","volume",
                "quote_volume","trades","taker_base","taker_quote"]:
        df[col] = df[col].astype(float)
    df["dollar_volume"] = df["quote_volume"]
    return df[["open","high","low","close","volume","dollar_volume",
               "trades","taker_base","taker_quote"]]

def build_dollar_bars(df: pd.DataFrame, threshold: float) -> pd.DataFrame:
    bars      = []
    cum_dv    = 0.0
    o         = None
    h         = -np.inf
    l         = np.inf
    vol       = 0.0
    trades    = 0.0
    t_base    = 0.0
    t_quote   = 0.0
    start_idx = None
    for ts, row in df.iterrows():
        if o is None:
            o         = row["open"]
            start_idx = ts
        h       = max(h, row["high"])
        l       = min(l, row["low"])
        vol    += row["volume"]
        cum_dv += row["dollar_volume"]
        trades += row["trades"]
        t_base += row["taker_base"]
        t_quote += row["taker_quote"]
        if cum_dv >= threshold:
            bars.append({
                "timestamp":    start_idx,
                "open":         o,
                "high":         h,
                "low":          l,
                "close":        row["close"],
                "volume":       vol,
                "dollar_volume": cum_dv,
                "trades":       trades,
                "taker_base":   t_base,
                "taker_quote":  t_quote,
            })
            o, h, l, vol, cum_dv = None, -np.inf, np.inf, 0.0, 0.0
            trades, t_base, t_quote = 0.0, 0.0, 0.0
    bar_df = pd.DataFrame(bars).set_index("timestamp")
    logging.info(f"dollar bars created: {len(bar_df)} bars (threshold=${threshold:,.0f})")
    return bar_df

if __name__ == "__main__":
    raw = fetch_ohlcv(SYMBOL, INTERVAL, YEARS)
    raw.to_csv("eth_hourly.csv")
    logging.info(f"hourly rows: {len(raw)}")
    dollar_bars = build_dollar_bars(raw, DOLLAR_BAR_THRESHOLD)
    dollar_bars.to_csv("eth_dollar_bars.csv")
    print(dollar_bars.tail())
    print(f"\ntotal dollar bars: {len(dollar_bars)}")
# Out:
# 2026-04-11 16:54:22,875 - INFO - fetched up to 2023-05-22 14:00:00.001000
# 2026-04-11 16:54:24,403 - INFO - fetched up to 2023-07-01 14:00:00.001000
# 2026-04-11 16:54:25,747 - INFO - fetched up to 2023-08-10 14:00:00.001000
# 2026-04-11 16:54:26,968 - INFO - fetched up to 2023-09-19 14:00:00.001000
# 2026-04-11 16:54:28,184 - INFO - fetched up to 2023-10-29 14:00:00.001000
# 2026-04-11 16:54:29,427 - INFO - fetched up to 2023-12-08 14:00:00.001000
# 2026-04-11 16:54:30,666 - INFO - fetched up to 2024-01-17 14:00:00.001000
# 2026-04-11 16:54:31,962 - INFO - fetched up to 2024-02-26 14:00:00.001000
# 2026-04-11 16:54:33,456 - INFO - fetched up to 2024-04-06 14:00:00.001000
# 2026-04-11 16:54:34,703 - INFO - fetched up to 2024-05-16 14:00:00.001000
# 2026-04-11 16:54:36,007 - INFO - fetched up to 2024-06-25 14:00:00.001000
# 2026-04-11 16:54:37,230 - INFO - fetched up to 2024-08-04 14:00:00.001000
# 2026-04-11 16:54:38,460 - INFO - fetched up to 2024-09-13 14:00:00.001000
# 2026-04-11 16:54:40,513 - INFO - fetched up to 2024-10-23 14:00:00.001000
# 2026-04-11 16:54:41,864 - INFO - fetched up to 2024-12-02 14:00:00.001000
# 2026-04-11 16:54:43,103 - INFO - fetched up to 2025-01-11 14:00:00.001000
# 2026-04-11 16:54:44,724 - INFO - fetched up to 2025-02-20 14:00:00.001000
# 2026-04-11 16:54:45,993 - INFO - fetched up to 2025-04-01 14:00:00.001000
# 2026-04-11 16:54:47,411 - INFO - fetched up to 2025-05-11 14:00:00.001000
# 2026-04-11 16:54:48,990 - INFO - fetched up to 2025-06-20 14:00:00.001000
# 2026-04-11 16:54:50,248 - INFO - fetched up to 2025-07-30 14:00:00.001000
# 2026-04-11 16:54:51,962 - INFO - fetched up to 2025-09-08 14:00:00.001000
# 2026-04-11 16:54:53,567 - INFO - fetched up to 2025-10-18 14:00:00.001000
# 2026-04-11 16:54:54,943 - INFO - fetched up to 2025-11-27 14:00:00.001000
# 2026-04-11 16:54:56,224 - INFO - fetched up to 2026-01-06 14:00:00.001000
# 2026-04-11 16:54:58,133 - INFO - fetched up to 2026-02-15 14:00:00.001000
# 2026-04-11 16:55:00,002 - INFO - fetched up to 2026-03-27 14:00:00.001000
# 2026-04-11 16:55:01,684 - INFO - fetched up to 2026-04-11 14:00:00.001000
# 2026-04-11 16:55:03,136 - INFO - hourly rows: 26280
# 2026-04-11 16:55:03,531 - INFO - dollar bars created: 2432 bars (threshold=$500,000,000)
#                         open     high      low    close       volume  \
# timestamp
# 2026-04-07 20:00:00  2113.39  2273.87  2110.68  2236.08  247137.4275
# 2026-04-08 01:00:00  2236.09  2270.55  2186.61  2195.22  262377.5019
# 2026-04-08 15:00:00  2195.23  2239.50  2158.19  2165.22  230252.4110
# 2026-04-09 14:00:00  2165.23  2246.00  2157.31  2185.86  229341.6139
# 2026-04-10 09:00:00  2185.85  2257.99  2185.83  2240.97  224981.5456
#
#                      dollar_volume     trades   taker_base   taker_quote
# timestamp
# 2026-04-07 20:00:00   5.444305e+08  2128156.0  130737.9239  2.878756e+08
# 2026-04-08 01:00:00   5.875891e+08  2421197.0  123220.5126  2.759392e+08
# 2026-04-08 15:00:00   5.052311e+08  3117121.0  107530.2278  2.360192e+08
# 2026-04-09 14:00:00   5.048280e+08  3092921.0  112248.6617  2.472261e+08
# 2026-04-10 09:00:00   5.023367e+08  2342246.0  111518.1944  2.490685e+08
#
# total dollar bars: 2432

# %%
# eda to get an overview
df = pd.read_csv("eth_dollar_bars.csv", parse_dates=True, index_col=0)
df["return"] = df["close"].pct_change() * 100

# bars per year (dynamic, not hardcoded)
total_years = (df.index[-1] - df.index[0]).days / 365
bars_per_year = len(df) / total_years

mean_return = df["return"].mean()
median_return = df["return"].median()
volatility = df["return"].std()
skewness = df["return"].skew()
kurtosis = df["return"].kurt()

bar_sharpe    = mean_return / volatility
annual_sharpe = bar_sharpe * np.sqrt(bars_per_year)  

var_95 = df["return"].quantile(0.05)
var_99 = df["return"].quantile(0.01)

print(f"bars total:     {len(df)}")
print(f"bars per year:  {bars_per_year:.0f}")
print(f"mean return:    {mean_return:.2f}%")
print(f"median return:  {median_return:.2f}%")
print(f"volatility:     {volatility:.2f}%")
print(f"skewness:       {skewness:.2f}")
print(f"kurtosis:       {kurtosis:.2f}")
print(f"bar sharpe:     {bar_sharpe:.2f}")
print(f"annual sharpe:  {annual_sharpe:.2f}")
print(f"q1 (25%):       {df['return'].quantile(0.25):.2f}%")
print(f"q3 (75%):       {df['return'].quantile(0.75):.2f}%")
print(f"var 95%:        {var_95:.2f}%")
print(f"var 99%:        {var_99:.2f}%")
# Out:
# bars total:     2432
# bars per year:  812
# mean return:    0.03%
# median return:  0.06%
# volatility:     2.21%
# skewness:       -0.02
# kurtosis:       1.36
# bar sharpe:     0.01
# annual sharpe:  0.40
# q1 (25%):       -1.36%
# q3 (75%):       1.39%
# var 95%:        -3.64%
# var 99%:        -5.45%

# %%
# testing for random walk
returns = df["return"].dropna()

# serial autocorrelation (de prado's primary motivation for dollar bars)
dw = durbin_watson(returns)
lb = acorr_ljungbox(returns, lags=[10, 20], return_df=True)

print(f"durbin-watson:  {dw:.2f}  (2.0 = no autocorr, <2 = positive)")
print(lb.to_string())

# also: plot acf/pacf
fig, axes = plt.subplots(1, 2, figsize=(14, 4))
sm.graphics.tsa.plot_acf(returns, lags=40, ax=axes[0], color='#FFB6C1')
sm.graphics.tsa.plot_pacf(returns, lags=40, ax=axes[1], color='#FFB6C1')
axes[0].set_title("acf dollar bar returns")
axes[1].set_title("pacf dollar bar returns")
plt.tight_layout()
plt.savefig("results/autocorrelation_dollar_bars.png", dpi=300, bbox_inches='tight')
plt.show()
# Out:
# durbin-watson:  1.94  (2.0 = no autocorr, <2 = positive)
#       lb_stat  lb_pvalue
# 10   7.809810   0.647408
# 20  14.071616   0.826846

# %%
# key insights:

# lag 0 spike correlation(today, today) = 1.0. always
# blue band: 95% confidence interval: roughly ±2 / sqrt(n)
# any bar inside = statistically indistinguishable from zero = no real pattern

# acf, autocorrelation function
# question: does today's return relate to the return N bars ago?
# lag 3 acf includes indirect influence from lags 1 and 2 as well

# pacf, partial autocorrelation function
# does today relate to N bars ago, after removing all the middlemen?


# durbin-watson: 1.94, scale runs 0 to 4
# 2.0 = no autocorrelation (each bar is independent of the last)
# < 2 = positive autocorrelation (good bars tend to follow good bars)
# > 2 = negative autocorrelation (good bars tend to flip to bad bars)


# ljung-box test
# across all lags up to N, is there *any* hidden autocorrelation hiding together?
# bundles them into one p-value
# p > 0.05 = no significant autocorrelation found (you fail to reject H0)
# p < 0.05 = something is there, worth investigating

#-> no memory, no exploitable linear structure in the return series itself

# %%
# rolling window: ~20 bars ≈ one trading day at this threshold
rolling_window = 20

fig, axes = plt.subplots(2, 2, figsize=(15, 10))
rcParams['font.family'] = 'DejaVu Sans'
rcParams['font.size'] = 12

axes[0,0].hist(df["return"].dropna(), bins=50, alpha=0.7, density=True,
               color='#FFB6C1', edgecolor='none')
for i, q_val in enumerate([0.05, 0.25, 0.5, 0.75, 0.95]):
    color = '#FF69B4' if i == 2 else '#FF1493'
    axes[0,0].axvline(df["return"].quantile(q_val),
                      color=color, linestyle='--', alpha=0.8, linewidth=2,
                      label=f'{q_val*100:.0f}%: {df["return"].quantile(q_val):.2f}%')
axes[0,0].set_title("Return Distribution Dollar Bars", fontsize=14, pad=15)
axes[0,0].legend(fontsize=10)
axes[0,0].set_xlabel("return per bar", fontsize=12)
axes[0,0].set_ylabel("density", fontsize=12)

stats.probplot(df["return"].dropna(), dist="norm", plot=axes[0,1])
axes[0,1].get_lines()[0].set_markerfacecolor('#FFB6C1')
axes[0,1].get_lines()[0].set_markeredgecolor('none')
axes[0,1].get_lines()[0].set_alpha(0.7)
axes[0,1].get_lines()[1].set_color('#FF69B4')
axes[0,1].get_lines()[1].set_linewidth(2)
axes[0,1].set_title("Q-Q Plot", fontsize=14, pad=15)

bp = axes[1,0].boxplot(df["return"].dropna(), patch_artist=True)
bp['boxes'][0].set_facecolor('#FFB6C1')
bp['boxes'][0].set_alpha(0.7)
bp['medians'][0].set_color('#FF69B4')
bp['medians'][0].set_linewidth(2)
for element in ['whiskers', 'fliers', 'caps']:
    for item in bp[element]:
        item.set_color('#FF69B4')
        item.set_alpha(0.8)
axes[1,0].set_ylabel("Return Per Bar %", fontsize=12)
axes[1,0].set_title("Return Boxplot Dollar Bars", fontsize=14, pad=15)

df["rolling_vol"] = df["return"].rolling(window=rolling_window).std()
axes[1,1].plot(df.index, df["rolling_vol"], color='#FFB6C1', linewidth=2)
axes[1,1].set_title(f"Rolling Volatility Window={rolling_window} Bars", fontsize=14, pad=15)
axes[1,1].set_ylabel("volatility", fontsize=12)
axes[1,1].set_xlabel("date", fontsize=12)

for ax in axes.flatten():
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.grid(True, color="gray", linestyle=(0, (10, 10)), linewidth=0.5, alpha=0.6)
    [t.set_color('#808079') for t in ax.yaxis.get_ticklabels()]
    [t.set_color('#808079') for t in ax.xaxis.get_ticklabels()]
    ax.tick_params(axis="x", colors="#808079")
    ax.tick_params(axis="y", colors="#808079")

axes[1,1].tick_params(axis='x', rotation=45)
plt.tight_layout()
plt.savefig("results/return_distribution_dollar_bars.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
# generate features, using the insights of the eda
df['return'] = df['close'].pct_change() * 100

# volatility
df['volatility_7b'] = df['close'].rolling(window=7).std().shift(1)

# volume_change still varies even in dollar bars
df['volume_change'] = df['volume'].pct_change().replace([np.inf, -np.inf], np.nan).shift(1)

# vol regime
vol_rolling_quantiles = df['close'].rolling(window=7).std().rolling(30)
df['vol_regime'] = np.where(
    df['volatility_7b'] > vol_rolling_quantiles.quantile(0.75).shift(1), 2,
    np.where(df['volatility_7b'] < vol_rolling_quantiles.quantile(0.25).shift(1), 0, 1)
)

df['vol_regime_change'] = (df['vol_regime'] != df['vol_regime'].shift(1)).astype(int)
df['vol_momentum']      = df['volatility_7b'] / df['volatility_7b'].shift(1).rolling(14).mean() - 1
df['vol_expansion']     = (df['volatility_7b'] > df['volatility_7b'].shift(1) * 1.5).astype(int)
df['vol_persistence']   = (df['volatility_7b'] > df['volatility_7b'].shift(1)).astype(int)

# extreme moves
df['extreme_down'] = (df['return'] < df['return'].rolling(90).quantile(0.05).shift(1)).astype(int)
df['extreme_up']   = (df['return'] > df['return'].rolling(90).quantile(0.95).shift(1)).astype(int)

extreme_events      = (df['extreme_down'] | df['extreme_up']).astype(int)
df['extreme_streak'] = extreme_events.groupby(
    (extreme_events != extreme_events.shift()).cumsum()
).cumsum()

# drawdown 
# threshold -0.15: price-based, not bar-based
df['running_max']   = df['close'].rolling(30).max().shift(1)
df['drawdown']      = (df['close'] - df['running_max']) / df['running_max']
df['deep_drawdown'] = (df['drawdown'] < -0.15).astype(int)

# volume 
df['volume_zscore'] = ((df['volume'] - df['volume'].rolling(30).mean()) /
                        df['volume'].rolling(30).std()).shift(1)

df['vwap']          = (df['volume'] * df['close']).rolling(20).sum() / df['volume'].rolling(20).sum()
df['vwap_distance'] = ((df['close'] - df['vwap'].shift(1)) / df['vwap'].shift(1))

# fat tails / var 
df['tail_risk_signal'] = ((df['volatility_7b'] > df['volatility_7b'].rolling(60).quantile(0.9).shift(1)) &
                           (df['volume_zscore'] > 1.5)).astype(int)

# capital flow
df["dollar_vol_z"] = ((df["dollar_volume"] - df["dollar_volume"].rolling(30).mean())
    / df["dollar_volume"].rolling(30).std()).shift(1)

# consecutive extreme moves: leading indicator for regime transitions
df["ret_raw"] = df["close"].pct_change(1).shift(1)
df["ret_5"]  = df["close"].pct_change(5).shift(1)

# 812 bars ≈ 1 year for dollar bars
bars_per_year = 812
df['var_breach_95'] = (df['return'].shift(1) < df['return'].rolling(bars_per_year).quantile(0.05).shift(1)).astype(int)
df['var_breach_99'] = (df['return'].shift(1) < df['return'].rolling(bars_per_year).quantile(0.01).shift(1)).astype(int)

df['position_size_factor'] = 1 / (df['volatility_7b'] / df['volatility_7b'].rolling(60).mean())
df['upside_momentum']      = (df['return'].shift(1) > df['return'].rolling(21).quantile(0.75).shift(1)).astype(int)

# talib 
def add_ta_indicators(df):
    for col in ['open','high','low','close','volume']:
        df[col] = df[col].astype('float64')

    df['open_lag1']   = df['open'].shift(1)
    df['high_lag1']   = df['high'].shift(1)
    df['low_lag1']    = df['low'].shift(1)
    df['close_lag1']  = df['close'].shift(1)
    df['volume_lag1'] = df['volume'].shift(1)

    df['atr_14'] = ta.ATR(df['high_lag1'], df['low_lag1'], df['close_lag1'], timeperiod=14)
    df['rsi']    = ta.RSI(df['close_lag1'], timeperiod=14)

    upper, middle, lower = ta.BBANDS(df['close_lag1'], timeperiod=20,
                                      nbdevup=2, nbdevdn=2, matype=0)
    df['bb_upper']    = upper
    df['bb_middle']   = middle
    df['bb_lower']    = lower
    df['bb_width']    = ((df['bb_upper'] - df['bb_lower']) / df['close_lag1']).fillna(0)
    df['bb_position'] = ((df['close_lag1'] - df['bb_lower']) /
                          (df['bb_upper'] - df['bb_lower'])).clip(0, 1)
    return df

df = add_ta_indicators(df)

df['atr_normalized']       = df['atr_14'] / df['close'].shift(1)
df['rsi_oversold_extreme']  = (df['rsi'] < 25).astype(int)
df['rsi_overbought_extreme'] = (df['rsi'] > 85).astype(int)

# market stress
df['market_stress'] = ((df['vol_regime'] == 2).astype(int) * 0.4 +
                        (df['volume_zscore'] > 2).astype(int) * 0.3 +
                        (df['extreme_streak'] > 2).astype(int) * 0.3)



# order flow features (taker = aggressive market orders)
df['taker_sell_vol']   = df['dollar_volume'] - df['taker_quote']

# order flow imbalance =buy pressure − sell pressure
df['ofi']              = ((df['taker_quote'] - df['taker_sell_vol']) /
                          (df['taker_quote'] + df['taker_sell_vol'])).shift(1)

df['trades_change']    = df['trades'].pct_change().replace([np.inf, -np.inf], np.nan).shift(1)

# trade_intensity z-scoring against rolling window becomes stationary:
df['trade_intensity']  = (df['trades'] / df['dollar_volume']).shift(1)
df['trade_intensity_z'] = ((df['trade_intensity'] - df['trade_intensity'].rolling(30).mean()) /
                            df['trade_intensity'].rolling(30).std()).shift(1)



df.drop(columns=['atr_14', 'vwap', 'running_max', 'trade_intensity', 'trades', 'extreme_up', 'extreme_down'], inplace=True, errors='ignore')

# %%
# check if nans are clustered at start or scattered throughout
print("nan location check:")
warmup_cutoff = 70  # max of any rolling window 

for col in df.columns[df.isnull().any()]:
    total    = df[col].isnull().sum()
    in_start = df[col].iloc[:warmup_cutoff].isnull().sum()
    scattered = total - in_start
    flag = "  PROBLEM: scattered nans, ffill silently corrupts" if scattered > 0 else ""
    print(f"  {col:30s} total={total:3d}  start={in_start:3d}  scattered={scattered:3d}{flag}")
# Out:
# nan location check:
#   return                         total=  1  start=  1  scattered=  0
#   rolling_vol                    total= 20  start= 20  scattered=  0
#   volatility_7b                  total=  7  start=  7  scattered=  0
#   volume_change                  total=  2  start=  2  scattered=  0
#   vol_momentum                   total= 21  start= 21  scattered=  0
#   drawdown                       total= 30  start= 30  scattered=  0
#   volume_zscore                  total= 30  start= 30  scattered=  0
#   vwap_distance                  total= 20  start= 20  scattered=  0
#   dollar_vol_z                   total= 30  start= 30  scattered=  0
#   ret_raw                        total=  2  start=  2  scattered=  0
#   ret_5                          total=  6  start=  6  scattered=  0
#   position_size_factor           total= 66  start= 66  scattered=  0
#   open_lag1                      total=  1  start=  1  scattered=  0
#   high_lag1                      total=  1  start=  1  scattered=  0
#   low_lag1                       total=  1  start=  1  scattered=  0
#   close_lag1                     total=  1  start=  1  scattered=  0
#   volume_lag1                    total=  1  start=  1  scattered=  0
#   rsi                            total= 15  start= 15  scattered=  0
#   bb_upper                       total= 20  start= 20  scattered=  0
#   bb_middle                      total= 20  start= 20  scattered=  0
#   bb_lower                       total= 20  start= 20  scattered=  0
#   bb_position                    total= 20  start= 20  scattered=  0
#   atr_normalized                 total= 15  start= 15  scattered=  0
#   ofi                            total=  1  start=  1  scattered=  0
#   trades_change                  total=  2  start=  2  scattered=  0
#   trade_intensity_z              total= 31  start= 31  scattered=  0

# %%
# replace inf with nan first
df.replace([np.inf, -np.inf], np.nan, inplace=True)

# check before filling
nan_report = df.isnull().sum()
nan_report = nan_report[nan_report > 0]
print("columns with nan:")
print(nan_report)

# only forward-fill, then drop remaining (warmup rows at the start)
df = df.ffill()
df.dropna(inplace=True)

print(f"remaining nulls: {df.isnull().sum().sum()}")
print(f"rows after cleanup: {len(df)}")
# Out:
# columns with nan:
# return                   1
# rolling_vol             20
# volatility_7b            7
# volume_change            2
# vol_momentum            21
# drawdown                30
# volume_zscore           30
# vwap_distance           20
# dollar_vol_z            30
# ret_raw                  2
# ret_5                    6
# position_size_factor    66
# open_lag1                1
# high_lag1                1
# low_lag1                 1
# close_lag1               1
# volume_lag1              1
# rsi                     15
# bb_upper                20
# bb_middle               20
# bb_lower                20
# bb_position             20
# atr_normalized          15
# ofi                      1
# trades_change            2
# trade_intensity_z       31
# dtype: int64
# remaining nulls: 0
# rows after cleanup: 2366

# %%
#showing all the columns
pd.set_option('display.max_columns', None)
df.head(3)
# Out:
#                         open     high      low    close       volume  \
# timestamp
# 2023-05-23 10:00:00  1855.19  1860.61  1812.13  1826.13  272884.8757
# 2023-05-24 06:00:00  1826.13  1826.45  1777.60  1800.41  280900.7479
# 2023-05-24 22:00:00  1800.42  1812.76  1761.41  1797.11  285461.7493
#
#                      dollar_volume   taker_base   taker_quote    return  \
# timestamp
# 2023-05-23 10:00:00   5.025608e+08  127568.7328  2.350507e+08 -1.566947
# 2023-05-24 06:00:00   5.056273e+08  132338.7289  2.381304e+08 -1.408443
# 2023-05-24 22:00:00   5.108251e+08  134885.5091  2.413564e+08 -0.183292
#
#                      rolling_vol  volatility_7b  volume_change  vol_regime  \
# timestamp
# 2023-05-23 10:00:00     1.508999      23.080888      -0.031178           0
# 2023-05-24 06:00:00     1.531131      23.097726      -0.006428           0
# 2023-05-24 22:00:00     1.497993      23.450490       0.029375           1
#
#                      vol_regime_change  vol_momentum  vol_expansion  \
# timestamp
# 2023-05-23 10:00:00                  0     -0.103106              0
# 2023-05-24 06:00:00                  0     -0.093599              0
# 2023-05-24 22:00:00                  1     -0.087125              0
#
#                      vol_persistence  extreme_streak  drawdown  deep_drawdown  \
# timestamp
# 2023-05-23 10:00:00                1               0 -0.077475              0
# 2023-05-24 06:00:00                1               0 -0.090468              0
# 2023-05-24 22:00:00                1               0 -0.092135              0
#
#                      volume_zscore  vwap_distance  tail_risk_signal  \
# timestamp
# 2023-05-23 10:00:00      -0.547514       0.002614                 0
# 2023-05-24 06:00:00      -0.663645      -0.010379                 0
# 2023-05-24 22:00:00      -0.115636      -0.010689                 0
#
#                      dollar_vol_z   ret_raw     ret_5  var_breach_95  \
# timestamp
# 2023-05-23 10:00:00     -0.644024  0.021361  0.028239              0
# 2023-05-24 06:00:00     -0.865149 -0.015669  0.026816              0
# 2023-05-24 22:00:00     -0.724574 -0.014084 -0.008284              0
#
#                      var_breach_99  position_size_factor  upside_momentum  \
# timestamp
# 2023-05-23 10:00:00              0              1.549442                1
# 2023-05-24 06:00:00              0              1.508760                0
# 2023-05-24 22:00:00              0              1.465483                0
#
#                      open_lag1  high_lag1  low_lag1  close_lag1  volume_lag1  \
# timestamp
# 2023-05-23 10:00:00    1816.40    1872.50   1813.33     1855.20  274650.4345
# 2023-05-24 06:00:00    1855.19    1860.61   1812.13     1826.13  272884.8757
# 2023-05-24 22:00:00    1826.13    1826.45   1777.60     1800.41  280900.7479
#
#                            rsi     bb_upper  bb_middle     bb_lower  bb_width  \
# timestamp
# 2023-05-23 10:00:00  52.985695  1881.388564  1822.5470  1763.705436  0.063434
# 2023-05-24 06:00:00  48.450907  1874.989854  1820.3335  1765.677146  0.059860
# 2023-05-24 22:00:00  44.797775  1870.150714  1817.5180  1764.885286  0.058467
#
#                      bb_position  atr_normalized  rsi_oversold_extreme  \
# timestamp
# 2023-05-23 10:00:00     0.777465        0.028630                     0
# 2023-05-24 06:00:00     0.553027        0.028905                     0
# 2023-05-24 22:00:00     0.337478        0.029162                     0
#
#                      rsi_overbought_extreme  market_stress  taker_sell_vol  \
# timestamp
# 2023-05-23 10:00:00                       0            0.0    2.675101e+08
# 2023-05-24 06:00:00                       0            0.0    2.674969e+08
# 2023-05-24 22:00:00                       0            0.0    2.694687e+08
#
#                           ofi  trades_change  trade_intensity_z
# timestamp
# 2023-05-23 10:00:00  0.185210      -0.242206           1.479679
# 2023-05-24 06:00:00 -0.064588       0.006130          -0.676223
# 2023-05-24 22:00:00 -0.058079       0.035070          -0.544279

# %%
df.columns
# Out:
# Index(['open', 'high', 'low', 'close', 'volume', 'dollar_volume', 'taker_base',
#        'taker_quote', 'return', 'rolling_vol', 'volatility_7b',
#        'volume_change', 'vol_regime', 'vol_regime_change', 'vol_momentum',
#        'vol_expansion', 'vol_persistence', 'extreme_streak', 'drawdown',
#        'deep_drawdown', 'volume_zscore', 'vwap_distance', 'tail_risk_signal',
#        'dollar_vol_z', 'ret_raw', 'ret_5', 'var_breach_95', 'var_breach_99',
#        'position_size_factor', 'upside_momentum', 'open_lag1', 'high_lag1',
#        'low_lag1', 'close_lag1', 'volume_lag1', 'rsi', 'bb_upper', 'bb_middle',
#        'bb_lower', 'bb_width', 'bb_position', 'atr_normalized',
#        'rsi_oversold_extreme', 'rsi_overbought_extreme', 'market_stress',
#        'taker_sell_vol', 'ofi', 'trades_change', 'trade_intensity_z'],
#       dtype='object')

# %%
# multicollinearity hygiene only, not feature selection
# feature importance comes later from mdi/mda on the trained model

feature_cols = [col for col in df.columns if col not in
                ['ticker', 'open', 'high', 'low', 'close', 'return',
                 'open_lag1', 'high_lag1', 'low_lag1', 'close_lag1',
                 'volume_lag1', 'bb_upper', 'bb_middle', 'bb_lower']]

correlation_matrix = df[feature_cols].corr()

def find_high_correlations(corr_matrix, threshold=0.85):
    pairs = []
    cols = corr_matrix.columns
    for i in range(len(cols)):
        for j in range(i + 1, len(cols)):
            val = corr_matrix.iloc[i, j]
            if abs(val) > threshold:
                pairs.append({'feature_1': cols[i], 'feature_2': cols[j], 'correlation': val})
    return pd.DataFrame(pairs).sort_values('correlation', key=abs, ascending=False)

def build_feature_clusters(corr_matrix, threshold=0.85):
    processed, clusters = set(), []
    for feat in corr_matrix.columns:
        if feat in processed:
            continue
        cluster = [feat]
        for other in corr_matrix.columns:
            if other != feat and other not in processed:
                if abs(corr_matrix.loc[feat, other]) > threshold:
                    cluster.append(other)
        if len(cluster) > 1:
            processed.update(cluster)
            clusters.append(cluster)
    return clusters

high_corr_df   = find_high_correlations(correlation_matrix, threshold=0.85)
feature_clusters = build_feature_clusters(correlation_matrix, threshold=0.85)

print("near-duplicate feature pairs (corr > 0.85):\n")
print(high_corr_df.to_string(index=False))
print("\nfeature clusters (redundant groups):\n")
for i, c in enumerate(feature_clusters):
    print(f"cluster {i+1}: {c}")

# style
rcParams['font.family'] = 'DejaVu Sans'
rcParams['font.size']   = 12

pastel_cmap = sns.diverging_palette(
    330,
    270,
    s=60,
    l=80,
    center="light",
    as_cmap=True
)

mask = np.triu(np.ones_like(correlation_matrix, dtype=bool))

plt.figure(figsize=(20, 16))
sns.heatmap(
    correlation_matrix,
    mask=mask,
    cmap=pastel_cmap,
    center=0,
    vmin=-1,
    vmax=1,
    square=True,
    linewidths=0.0,
    cbar_kws={'label': 'correlation', 'shrink': 0.8}
)
plt.title('feature correlation matrix (multicollinearity check)', fontsize=14, pad=15)
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.savefig("results/correlation.png", dpi=300, bbox_inches='tight')
plt.show()
# Out:
# near-duplicate feature pairs (corr > 0.85):
#
#     feature_1      feature_2  correlation
#        volume     taker_base     0.976197
# dollar_volume taker_sell_vol     0.900452
# dollar_volume    taker_quote     0.893362
#           rsi    bb_position     0.886014
# vwap_distance            rsi     0.861521
# vwap_distance    bb_position     0.850514
#
# feature clusters (redundant groups):
#
# cluster 1: ['volume', 'taker_base']
# cluster 2: ['dollar_volume', 'taker_quote', 'taker_sell_vol']
# cluster 3: ['vwap_distance', 'rsi', 'bb_position']

# %%
# base ssset = the traded unit (ETH)
# taker_base = sum of all market buy orders in the base asset

# volume = total traded volume → includes: market buys (taker buy), market sells (taker sell)

# dollar_volume = price × volume, measures capital flow in USD
# taker_sell_vol = volume of market sell orders

# when the market is active:
# high trading activity → high taker_sell → high dollar_volume

# dollar_volume = capital flow
# taker_sell_vol = selling pressure

# all three features (vwap_distance, rsi, bb_position) are retained
# high inter-feature correlation does not imply low predictive value
# final selection deferred to mdi/mda, importance scores post-training

# %%
# test all features for stationarity
# adf, augmented dickey-fuller, checks if a series has a unit root (= drifts systematically over time)
# p < 0.05: stationary 
# p >= 0.05: non-stationary, needs differencing 
# this is not feature selection: all stationary features proceed to training
# importance ranking happens post-training via mdi/mda

def adf_test(series: pd.Series, name: str) -> dict:
    clean = series.dropna()
    # skip binary/constant features, adf meaningless there
    if clean.nunique() <= 2 or clean.std() == 0:
        return {'feature': name, 'adf_stat': None, 'p_value': None,
                'stationary': True, 'note': 'binary/constant - skipped'}
    result = adfuller(clean, autolag='AIC')
    return {
        'feature':    name,
        'adf_stat':   round(result[0], 4),
        'p_value':    round(result[1], 4),
        'stationary': result[1] < 0.05,
        'note':       'ok' if result[1] < 0.05 else 'NON-STATIONARY',
    }

results = pd.DataFrame([adf_test(df[f], f) for f in feature_cols if f in df.columns])
results = results.sort_values('p_value', na_position='last')
print(results.to_string(index=False))
print("─" * 70)
print(f"stationary:     {results['stationary'].sum()} / {len(results)}")
print(f"non-stationary: {(~results['stationary']).sum()} / {len(results)}")

stationary_features = results[results['stationary']]['feature'].tolist()
# Out:
#                feature  adf_stat  p_value  stationary                      note
#          vwap_distance  -10.1875   0.0000        True                        ok
#                    ofi  -19.8190   0.0000        True                        ok
#         taker_sell_vol  -11.0349   0.0000        True                        ok
#          market_stress  -18.4855   0.0000        True                        ok
#            bb_position  -11.9378   0.0000        True                        ok
#               bb_width   -7.7559   0.0000        True                        ok
#                    rsi   -8.8463   0.0000        True                        ok
#   position_size_factor  -13.9197   0.0000        True                        ok
#                  ret_5   -8.5799   0.0000        True                        ok
#                ret_raw  -47.2490   0.0000        True                        ok
#           dollar_vol_z  -18.9291   0.0000        True                        ok
#          trades_change  -21.2296   0.0000        True                        ok
#      trade_intensity_z  -13.9255   0.0000        True                        ok
#               drawdown   -7.7057   0.0000        True                        ok
#         extreme_streak  -44.5507   0.0000        True                        ok
#           vol_momentum  -12.9909   0.0000        True                        ok
#             vol_regime  -19.8147   0.0000        True                        ok
#          volume_change  -34.5390   0.0000        True                        ok
#          volatility_7b   -9.1610   0.0000        True                        ok
#            taker_quote  -10.7979   0.0000        True                        ok
#          dollar_volume  -10.2871   0.0000        True                        ok
#          volume_zscore  -13.7222   0.0000        True                        ok
#         atr_normalized   -4.7371   0.0001        True                        ok
#            rolling_vol   -4.4921   0.0002        True                        ok
#                 volume   -3.3850   0.0115        True                        ok
#             taker_base   -2.9001   0.0453        True                        ok
#      vol_regime_change       NaN      NaN        True binary/constant - skipped
#          vol_expansion       NaN      NaN        True binary/constant - skipped
#        vol_persistence       NaN      NaN        True binary/constant - skipped
#          deep_drawdown       NaN      NaN        True binary/constant - skipped
#       tail_risk_signal       NaN      NaN        True binary/constant - skipped
#          var_breach_95       NaN      NaN        True binary/constant - skipped
#          var_breach_99       NaN      NaN        True binary/constant - skipped
#        upside_momentum       NaN      NaN        True binary/constant - skipped
#   rsi_oversold_extreme       NaN      NaN        True binary/constant - skipped
# rsi_overbought_extreme       NaN      NaN        True binary/constant - skipped
# ──────────────────────────────────────────────────────────────────────
# stationary:     36 / 36
# non-stationary: 0 / 36

# %%
# check if binary features are actually binary or just constant
# rough threshold: feature needs at least ~1% positive cases to be learnable
for f in stationary_features:
    n = df[f].nunique()
    if n <= 2:
        print(f"{f}: {df[f].value_counts().to_dict()}")
# Out:
# vol_regime_change: {0: 1688, 1: 678}
# vol_expansion: {0: 2236, 1: 130}
# vol_persistence: {0: 1192, 1: 1174}
# deep_drawdown: {0: 2061, 1: 305}
# tail_risk_signal: {0: 2302, 1: 64}
# var_breach_95: {0: 2277, 1: 89}
# var_breach_99: {0: 2347, 1: 19}
# upside_momentum: {0: 1825, 1: 541}
# rsi_oversold_extreme: {0: 2326, 1: 40}
# rsi_overbought_extreme: {0: 2363, 1: 3}

# %%
rare_binary = ['rsi_overbought_extreme', 'var_breach_99',
               'rsi_oversold_extreme', ]#'tail_risk_signal'
stationary_features = [f for f in stationary_features if f not in rare_binary]
df.drop(columns=rare_binary, inplace=True, errors='ignore')

# %%
# checking columns, which ones to exclude for graph
print(df.dtypes)
# Out:
# open                    float64
# high                    float64
# low                     float64
# close                   float64
# volume                  float64
# dollar_volume           float64
# taker_base              float64
# taker_quote             float64
# return                  float64
# rolling_vol             float64
# volatility_7b           float64
# volume_change           float64
# vol_regime                int64
# vol_regime_change         int64
# vol_momentum            float64
# vol_expansion             int64
# vol_persistence           int64
# extreme_streak            int64
# drawdown                float64
# deep_drawdown             int64
# volume_zscore           float64
# vwap_distance           float64
# tail_risk_signal          int64
# dollar_vol_z            float64
# ret_raw                 float64
# ret_5                   float64
# var_breach_95             int64
# position_size_factor    float64
# upside_momentum           int64
# open_lag1               float64
# high_lag1               float64
# low_lag1                float64
# close_lag1              float64
# volume_lag1             float64
# rsi                     float64
# bb_upper                float64
# bb_middle               float64
# bb_lower                float64
# bb_width                float64
# bb_position             float64
# atr_normalized          float64
# market_stress           float64
# taker_sell_vol          float64
# ofi                     float64
# trades_change           float64
# trade_intensity_z       float64
# dtype: object

# %%
# causal discovery requires continuous, non-derived features only
# binary and composite features violate fisherz assumptions

cd_exclude = [
    'vol_regime_change',
    'vol_expansion',
    'vol_persistence',
    'extreme_down',
    'extreme_up',
    'deep_drawdown',
    'volume_spike',
    'tail_risk_signal',
    'var_breach_95',
    'upside_momentum'
]

cd_features = [f for f in stationary_features if f not in cd_exclude]

node_names = cd_features  

data_cd    = df[cd_features].dropna()
data_array = data_cd.values.astype(np.float64)
print(f"observations: {data_array.shape[0]}, features: {data_array.shape[1]}")
print(f"cd_features: {cd_features}")
# Out:
# observations: 2366, features: 26
# cd_features: ['vwap_distance', 'ofi', 'taker_sell_vol', 'market_stress', 'bb_position', 'bb_width', 'rsi', 'position_size_factor', 'ret_5', 'ret_raw', 'dollar_vol_z', 'trades_change', 'trade_intensity_z', 'drawdown', 'extreme_streak', 'vol_momentum', 'vol_regime', 'volume_change', 'volatility_7b', 'taker_quote', 'dollar_volume', 'volume_zscore', 'atr_normalized', 'rolling_vol', 'volume', 'taker_base']

# %%
from scipy.stats import rankdata

# rank-transform each feature to make parcorr more robust
data_pcmci = df[cd_features].dropna().values.astype(np.float64)
for i in range(data_pcmci.shape[1]):
    data_pcmci[:, i] = rankdata(data_pcmci[:, i]) / len(data_pcmci[:, i])

dataframe = pp.DataFrame(
    data_pcmci,
    datatime=np.arange(data_pcmci.shape[0]),
    var_names=cd_features
)

pcmci = PCMCI(
    dataframe=dataframe,
    cond_ind_test=ParCorr(significance='analytic'),
    verbosity=0
)

results = pcmci.run_pcmci(tau_min=1, tau_max=5, pc_alpha=0.05)


p_matrix   = results['p_matrix']
val_matrix = results['val_matrix']

pcmci_edges = []
for i, target in enumerate(cd_features):
    for j, source in enumerate(cd_features):
        for lag in range(1, 6):
            p   = p_matrix[i, j, lag]
            val = val_matrix[i, j, lag]
            if p < 0.05:
                pcmci_edges.append({
                    'source':   source,
                    'target':   target,
                    'lag':      lag,
                    'strength': round(abs(val), 2),
                    'p_value':  round(p, 2),
                })

edge_df_pcmci = (pd.DataFrame(pcmci_edges)
                   .sort_values('strength', ascending=False)
                   .reset_index(drop=True))

print("─" * 70)
print("pcmci results, significant causal links:")
print("─" * 70)
print(edge_df_pcmci.to_string(index=False))
print("─" * 70)
print(f"total significant causal links: {len(edge_df_pcmci)}")

threshold = 0.15
edge_df_filtered = edge_df_pcmci[
    (edge_df_pcmci['strength'] >= threshold) &
    (edge_df_pcmci['source'] != edge_df_pcmci['target'])
].copy()

G_top = nx.DiGraph()
for _, row in edge_df_filtered.iterrows():
    G_top.add_edge(row['source'], row['target'],
                   weight=row['strength'],
                   lag=row['lag'])

category_colors = {
    # price / drawdown
    'drawdown':           '#FFB6C1',
    # volatility regime
    'volatility_7b':      '#c9a0dc',
    'vol_momentum':       '#c9a0dc',
    'vol_regime':         '#c9a0dc',
    'rolling_vol':        '#c9a0dc',
    # volume
    'volume_change':      '#a8c8e8',
    'volume_zscore':      '#a8c8e8',
    'dollar_vol_z':       '#a8c8e8',
    'dollar_volume':      '#a8c8e8',
    'volume':             '#a8c8e8',
    # technical
    'bb_width':           '#b8e0c8',
    'bb_position':        '#b8e0c8',
    'atr_normalized':     '#b8e0c8',
    'vwap_distance':      '#b8e0c8',
    'rsi':                '#b8e0c8',
    # order flow
    'ofi':                '#ffd9a8',
    'taker_sell_vol':     '#ffd9a8',
    'taker_quote':        '#ffd9a8',
    'taker_base':         '#ffd9a8',
    'trades_change':      '#ffd9a8',
    'trade_intensity_z':  '#ffd9a8',
    # returns
    'ret_raw':            '#c8e8e8',
    'ret_5':              '#c8e8e8',
    # other
    'extreme_streak':     '#d4d4c8',
    'market_stress':      '#d4d4c8',
    'position_size_factor': '#d4d4c8',
}

# classify nodes as sink or hub by in/out degree ratio
in_deg  = dict(G_top.in_degree())
out_deg = dict(G_top.out_degree())
node_border_color = []
node_border_width = []
for n in G_top.nodes():
    i = in_deg.get(n, 0)
    o = out_deg.get(n, 0)
    if o == 0 or (i > 0 and i / max(o, 1) >= 2.5):
        node_border_color.append('#e05555')
        node_border_width.append(3.5)
    elif o >= 3 and o > i:
        node_border_color.append('#5588cc')
        node_border_width.append(3.5)
    else:
        node_border_color.append('#aaaaaa')
        node_border_width.append(1.0)

node_colors = [category_colors.get(n, '#e0e0d8') for n in G_top.nodes()]
edge_widths = [G_top[u][v]['weight'] * 6 for u, v in G_top.edges()]
edge_labels = {(u, v): f"l{G_top[u][v]['lag']} {G_top[u][v]['weight']:.2f}"
               for u, v in G_top.edges()}

rcParams['font.family'] = 'DejaVu Sans'
rcParams['font.size']   = 12

fig, ax = plt.subplots(figsize=(20, 14))
ax.set_facecolor('white')
fig.patch.set_facecolor('white')

pos = nx.spring_layout(G_top, seed=42, k=3.0)

nx.draw_networkx_nodes(G_top, pos, node_color=node_colors,
                       node_size=2400, alpha=0.9, ax=ax,
                       edgecolors=node_border_color,
                       linewidths=node_border_width)

nx.draw_networkx_labels(G_top, pos, font_size=8,
                        font_color='#404040', font_weight='bold', ax=ax)

nx.draw_networkx_edges(G_top, pos, width=edge_widths,
                       edge_color='#FFB6C1', arrows=True,
                       arrowsize=40, alpha=0.75,
                       connectionstyle='arc3,rad=0.12', ax=ax)

nx.draw_networkx_edge_labels(G_top, pos, edge_labels=edge_labels,
                              font_size=6, font_color='#606060',
                              alpha=0.9, ax=ax)

legend = [
    mpatches.Patch(color='#FFB6C1', label='price / drawdown'),
    mpatches.Patch(color='#c9a0dc', label='volatility regime'),
    mpatches.Patch(color='#a8c8e8', label='volume'),
    mpatches.Patch(color='#b8e0c8', label='technical'),
    mpatches.Patch(color='#ffd9a8', label='order flow'),
    mpatches.Patch(color='#c8e8e8', label='returns'),
    mpatches.Patch(color='#d4d4c8', label='other'),
    mpatches.Patch(edgecolor='#e05555', facecolor='none',
                   label='sink node (result)', linewidth=2),
    mpatches.Patch(edgecolor='#5588cc', facecolor='none',
                   label='hub / driver', linewidth=2),
]
ax.legend(handles=legend, loc='lower left', fontsize=9, framealpha=0.8)

for spine in ax.spines.values():
    spine.set_visible(False)

ax.set_title(f'ETH causal graph PCMCI (strength ≥ {threshold}, parcorr, α=0.05)',
             fontsize=14, pad=15, color='#404040')
ax.axis('off')
plt.tight_layout()
plt.savefig("results/pcmci_dag.png", dpi=300, bbox_inches='tight')
plt.show()
# Out:
# ──────────────────────────────────────────────────────────────────────
# pcmci results, significant causal links:
# ──────────────────────────────────────────────────────────────────────
#               source               target  lag  strength  p_value
#          bb_position        vwap_distance    1      0.93     0.00
#         dollar_vol_z        dollar_volume    1      0.89     0.00
#              ret_raw        vwap_distance    1      0.87     0.00
#                  ofi       taker_sell_vol    1      0.86     0.00
#    trade_intensity_z        trades_change    1      0.86     0.00
#                  rsi        vwap_distance    1      0.85     0.00
#             bb_width             bb_width    1      0.83     0.00
#                ret_5        vwap_distance    1      0.79     0.00
#              ret_raw        vwap_distance    2      0.79     0.00
#                  ofi          taker_quote    1      0.75     0.00
#                  rsi        vwap_distance    2      0.74     0.00
#       atr_normalized       atr_normalized    1      0.71     0.00
#          rolling_vol          rolling_vol    1      0.70     0.00
#          bb_position        vwap_distance    2      0.70     0.00
#        volatility_7b        volatility_7b    1      0.69     0.00
# position_size_factor position_size_factor    1      0.69     0.00
#        vwap_distance        vwap_distance    1      0.69     0.00
#                  rsi                  rsi    1      0.66     0.00
#                ret_5                ret_5    1      0.63     0.00
#          bb_position          bb_position    1      0.61     0.00
#         dollar_vol_z         dollar_vol_z    1      0.58     0.00
#              ret_raw             drawdown    2      0.57     0.00
#                ret_5              ret_raw    4      0.56     0.00
#    trade_intensity_z    trade_intensity_z    1      0.56     0.00
#         dollar_vol_z         dollar_vol_z    2      0.53     0.00
#         dollar_vol_z         dollar_vol_z    3      0.52     0.00
#         dollar_vol_z         dollar_vol_z    4      0.49     0.00
#        volume_change               volume    1      0.48     0.00
#         dollar_vol_z         dollar_vol_z    5      0.48     0.00
#        volume_zscore        dollar_volume    1      0.46     0.00
#        trades_change        trades_change    1      0.43     0.00
#                  ofi               volume    1      0.43     0.00
#         vol_momentum         vol_momentum    1      0.42     0.00
#       atr_normalized       extreme_streak    1      0.41     0.00
#             drawdown             drawdown    1      0.41     0.00
#              ret_raw       taker_sell_vol    1      0.40     0.00
#              ret_raw        vwap_distance    3      0.40     0.00
#        volume_change               volume    2      0.39     0.00
#                ret_5              ret_raw    5      0.37     0.00
#              ret_raw             drawdown    1      0.35     0.00
#                  ofi        vwap_distance    1      0.35     0.00
#        volume_change          taker_quote    2      0.34     0.00
#        market_stress        market_stress    1      0.34     0.00
#              ret_raw             drawdown    3      0.32     0.00
#        volume_zscore        volume_zscore    1      0.31     0.00
#    trade_intensity_z           taker_base    2      0.31     0.00
#         vol_momentum       extreme_streak    1      0.31     0.00
#              ret_raw          taker_quote    1      0.30     0.00
#           vol_regime         vol_momentum    1      0.30     0.00
#          bb_position             drawdown    1      0.30     0.00
#        volatility_7b       extreme_streak    1      0.30     0.00
# position_size_factor       extreme_streak    1      0.30     0.00
#         dollar_vol_z               volume    1      0.29     0.00
#             bb_width             bb_width    2      0.28     0.00
#                ret_5        vwap_distance    2      0.27     0.00
#        volume_change       taker_sell_vol    2      0.27     0.00
#                  rsi             drawdown    1      0.27     0.00
#        volume_change        dollar_volume    1      0.26     0.00
#        volume_change        dollar_volume    2      0.26     0.00
#                ret_5              ret_raw    3      0.25     0.00
#              ret_raw        vwap_distance    4      0.25     0.00
#        market_stress         vol_momentum    1      0.25     0.00
#         dollar_vol_z        volume_zscore    1      0.25     0.00
#         vol_momentum         vol_momentum    2      0.25     0.00
#             bb_width        vwap_distance    1      0.24     0.00
#        volume_zscore        volume_zscore    3      0.24     0.00
#         dollar_vol_z        volume_zscore    5      0.24     0.00
#                ret_5              ret_raw    1      0.24     0.00
#        volume_zscore        volume_zscore    2      0.24     0.00
#       atr_normalized          rolling_vol    1      0.23     0.00
#           vol_regime       extreme_streak    1      0.23     0.00
#               volume               volume    1      0.23     0.00
#         dollar_vol_z        volume_zscore    2      0.23     0.00
#    trade_intensity_z       taker_sell_vol    2      0.23     0.00
#        volume_zscore        dollar_volume    2      0.23     0.00
#    trade_intensity_z               volume    4      0.22     0.00
#           vol_regime           vol_regime    1      0.22     0.00
#       atr_normalized        vwap_distance    1      0.22     0.00
#    trade_intensity_z        trades_change    2      0.22     0.00
#         dollar_vol_z        volume_zscore    4      0.21     0.00
#           taker_base               volume    1      0.21     0.00
#              ret_raw             drawdown    4      0.21     0.00
#    trade_intensity_z           taker_base    3      0.21     0.00
#         dollar_vol_z        volume_zscore    3      0.21     0.00
#                ret_5              ret_raw    2      0.21     0.00
#        volume_zscore         dollar_vol_z    5      0.21     0.00
#        volume_zscore        volume_zscore    4      0.20     0.00
#        trades_change          taker_quote    2      0.20     0.00
#        volume_change       taker_sell_vol    1      0.20     0.00
#        volume_change           taker_base    2      0.20     0.00
#        volume_zscore        volume_zscore    5      0.20     0.00
#    trade_intensity_z               volume    3      0.20     0.00
#        volume_zscore       taker_sell_vol    5      0.20     0.00
#        volume_zscore               volume    2      0.19     0.00
#        market_stress               volume    1      0.19     0.00
#       atr_normalized               volume    1      0.19     0.00
#    trade_intensity_z    trade_intensity_z    2      0.19     0.00
#        volume_zscore       taker_sell_vol    1      0.19     0.00
#              ret_raw        vwap_distance    5      0.19     0.00
#                  ofi           taker_base    1      0.19     0.00
#       atr_normalized        vwap_distance    2      0.18     0.00
#        volume_zscore           taker_base    2      0.18     0.00
#       atr_normalized          rolling_vol    2      0.18     0.00
#       atr_normalized             drawdown    1      0.18     0.00
#             bb_width             drawdown    1      0.18     0.00
#        volume_zscore       taker_sell_vol    2      0.18     0.00
#        volume_zscore         dollar_vol_z    2      0.17     0.00
#        volatility_7b        dollar_volume    1      0.17     0.00
#        market_stress       extreme_streak    1      0.17     0.00
#         vol_momentum        dollar_volume    1      0.17     0.00
#             bb_width        vwap_distance    2      0.17     0.00
#        volume_zscore       taker_sell_vol    4      0.17     0.00
#        volume_zscore        vwap_distance    1      0.17     0.00
#        volume_change        dollar_volume    3      0.17     0.00
#    trade_intensity_z           taker_base    4      0.17     0.00
#        volume_zscore        dollar_volume    4      0.17     0.00
# position_size_factor        dollar_volume    1      0.17     0.00
#                ret_5        vwap_distance    5      0.16     0.00
#         dollar_vol_z        volume_change    1      0.16     0.00
#         dollar_vol_z             drawdown    4      0.16     0.00
#        volume_zscore        dollar_volume    5      0.16     0.00
#        volume_change        vwap_distance    1      0.16     0.00
#         dollar_vol_z        dollar_volume    3      0.16     0.00
#        trades_change               volume    1      0.16     0.00
#         dollar_vol_z        dollar_volume    4      0.16     0.00
#                  ofi        vwap_distance    2      0.16     0.00
#        trades_change               volume    3      0.15     0.00
#        trades_change           taker_base    1      0.15     0.00
#        volume_change         dollar_vol_z    5      0.15     0.00
#             bb_width       extreme_streak    1      0.15     0.00
#        volume_zscore         dollar_vol_z    3      0.15     0.00
#        volume_zscore         dollar_vol_z    1      0.15     0.00
#             bb_width             drawdown    2      0.15     0.00
#              ret_raw             drawdown    5      0.15     0.00
#        volume_zscore               volume    5      0.14     0.00
#         dollar_vol_z        volume_change    5      0.14     0.00
#         dollar_vol_z        volume_change    4      0.14     0.00
#         dollar_vol_z        volume_change    3      0.14     0.00
#         dollar_vol_z        volume_change    2      0.14     0.00
# position_size_factor position_size_factor    2      0.14     0.00
#              ret_raw           taker_base    2      0.14     0.00
# position_size_factor          rolling_vol    1      0.14     0.00
#         dollar_vol_z        dollar_volume    2      0.14     0.00
#           taker_base               volume    3      0.14     0.00
#        volume_change         dollar_vol_z    4      0.14     0.00
#           taker_base        dollar_volume    1      0.14     0.00
#    trade_intensity_z               volume    2      0.14     0.00
#        volatility_7b          rolling_vol    1      0.14     0.00
#        volume_zscore           taker_base    1      0.14     0.00
#             bb_width       taker_sell_vol    1      0.14     0.00
#             bb_width              ret_raw    1      0.14     0.00
#         dollar_vol_z        dollar_volume    5      0.14     0.00
#                  rsi             drawdown    2      0.14     0.00
#        trades_change       taker_sell_vol    1      0.14     0.00
#       taker_sell_vol       taker_sell_vol    1      0.14     0.00
#         dollar_vol_z       taker_sell_vol    4      0.13     0.00
#         dollar_vol_z       taker_sell_vol    3      0.13     0.00
#                ret_5                  rsi    1      0.13     0.00
#         dollar_vol_z       taker_sell_vol    5      0.13     0.00
#        volume_change         dollar_vol_z    3      0.13     0.00
#                ret_5                  rsi    2      0.13     0.00
#         vol_momentum          rolling_vol    1      0.13     0.00
#        volume_zscore          taker_quote    2      0.13     0.00
#                ret_5                  ofi    2      0.13     0.00
#       atr_normalized        dollar_volume    1      0.13     0.00
# position_size_factor       extreme_streak    4      0.13     0.00
#                ret_5             drawdown    3      0.13     0.00
#         dollar_vol_z        vwap_distance    4      0.13     0.00
#                ret_5          bb_position    2      0.13     0.00
#        volume_change             drawdown    1      0.13     0.00
#        volume_zscore         dollar_vol_z    4      0.13     0.00
#        volume_change              ret_raw    1      0.12     0.00
#                  ofi             drawdown    1      0.12     0.00
#        volatility_7b       extreme_streak    4      0.12     0.00
#                ret_5             drawdown    4      0.12     0.00
#        trades_change           taker_base    3      0.12     0.00
#    trade_intensity_z        dollar_volume    4      0.12     0.00
#        volume_zscore          taker_quote    5      0.12     0.00
#               volume               volume    3      0.12     0.00
#    trade_intensity_z        market_stress    1      0.12     0.00
#          bb_position       taker_sell_vol    1      0.12     0.00
#           vol_regime          rolling_vol    1      0.12     0.00
#                ret_5             bb_width    5      0.12     0.00
#        trades_change       taker_sell_vol    3      0.12     0.00
#    trade_intensity_z       taker_sell_vol    4      0.12     0.00
# position_size_factor        market_stress    1      0.11     0.00
#        trades_change             drawdown    2      0.11     0.00
#        volume_zscore          taker_quote    4      0.11     0.00
#        volatility_7b       extreme_streak    5      0.11     0.00
#        trades_change        dollar_volume    3      0.11     0.00
#        dollar_volume        dollar_volume    1      0.11     0.00
#        volatility_7b        market_stress    1      0.11     0.00
#        trades_change       taker_sell_vol    2      0.11     0.00
#        volume_change       taker_sell_vol    3      0.11     0.00
#        trades_change        vwap_distance    2      0.11     0.00
#    trade_intensity_z                  ofi    2      0.11     0.00
#                ret_5                  ofi    5      0.11     0.00
#               volume               volume    5      0.11     0.00
#        volume_change         dollar_vol_z    2      0.11     0.00
#               volume        vwap_distance    1      0.11     0.00
#           taker_base               volume    5      0.11     0.00
#        volume_change        vwap_distance    2      0.11     0.00
#        volume_change             drawdown    2      0.11     0.00
#             bb_width position_size_factor    1      0.11     0.00
#              ret_raw          taker_quote    2      0.11     0.00
#           vol_regime         vol_momentum    3      0.11     0.00
#         dollar_vol_z          taker_quote    4      0.11     0.00
#    trade_intensity_z        volume_change    1      0.11     0.00
#           vol_regime       extreme_streak    4      0.11     0.00
#           vol_regime position_size_factor    1      0.11     0.00
#                ret_5                ret_5    2      0.11     0.00
#         dollar_vol_z          taker_quote    5      0.10     0.00
#       atr_normalized             drawdown    2      0.10     0.00
#                ret_5       taker_sell_vol    1      0.10     0.00
#              ret_raw               volume    1      0.10     0.00
#         dollar_vol_z               volume    3      0.10     0.00
#         dollar_vol_z               volume    5      0.10     0.00
#         dollar_vol_z               volume    4      0.10     0.00
#        trades_change        trades_change    2      0.10     0.00
#    trade_intensity_z       extreme_streak    2      0.10     0.00
#        volume_zscore        volume_change    2      0.10     0.00
#                ret_5                  ofi    1      0.10     0.00
#        volatility_7b       extreme_streak    3      0.10     0.00
#         vol_momentum       extreme_streak    3      0.10     0.00
#         vol_momentum          rolling_vol    5      0.10     0.00
#               volume          taker_quote    3      0.10     0.00
#        volume_zscore          taker_quote    1      0.10     0.00
#                ret_5                ret_5    5      0.10     0.00
#                ret_5                ret_5    4      0.10     0.00
#          taker_quote          taker_quote    1      0.10     0.00
#    trade_intensity_z          taker_quote    3      0.10     0.00
#         dollar_vol_z          taker_quote    3      0.10     0.00
#           vol_regime        dollar_volume    1      0.10     0.00
#          bb_position          taker_quote    1      0.10     0.00
# position_size_factor       extreme_streak    3      0.10     0.00
#        trades_change          taker_quote    1      0.10     0.00
#        volume_change        volume_zscore    5      0.10     0.00
# position_size_factor       extreme_streak    5      0.10     0.00
#        volatility_7b         vol_momentum    1      0.09     0.00
#    trade_intensity_z         dollar_vol_z    2      0.09     0.00
#    trade_intensity_z         vol_momentum    1      0.09     0.00
#           vol_regime       extreme_streak    5      0.09     0.00
#    trade_intensity_z        volatility_7b    1      0.09     0.00
#        volume_zscore               volume    4      0.09     0.00
#                ret_5             drawdown    2      0.09     0.00
#        volume_change               volume    3      0.09     0.00
#           taker_base          taker_quote    3      0.09     0.00
#         vol_momentum       extreme_streak    5      0.09     0.00
#        volatility_7b        volatility_7b    2      0.09     0.00
#         vol_momentum       extreme_streak    4      0.09     0.00
#        volume_zscore               volume    1      0.09     0.00
#        volume_zscore             drawdown    3      0.09     0.00
#         dollar_vol_z        market_stress    2      0.09     0.00
#                ret_5             bb_width    4      0.09     0.00
#           taker_base              ret_raw    1      0.09     0.00
#    trade_intensity_z position_size_factor    1      0.09     0.00
#               volume              ret_raw    1      0.09     0.00
#                ret_5        vwap_distance    3      0.09     0.00
#        market_stress             bb_width    1      0.09     0.00
#                ret_5             bb_width    2      0.08     0.00
#               volume        dollar_volume    1      0.08     0.00
#        dollar_volume         dollar_vol_z    4      0.08     0.00
#        market_stress       extreme_streak    4      0.08     0.00
#        market_stress          rolling_vol    1      0.08     0.00
#                  ofi       extreme_streak    1      0.08     0.00
#                ret_5          taker_quote    1      0.08     0.00
#                  rsi               volume    1      0.08     0.00
#    trade_intensity_z        market_stress    2      0.08     0.00
#        volume_zscore              ret_raw    3      0.08     0.00
#          bb_position                ret_5    1      0.08     0.00
# position_size_factor               volume    1      0.08     0.00
#                ret_5               volume    1      0.08     0.00
#         dollar_vol_z        market_stress    5      0.08     0.00
#              ret_raw               volume    2      0.08     0.00
#           vol_regime           vol_regime    3      0.08     0.00
#           vol_regime        volatility_7b    1      0.08     0.00
#              ret_raw        volume_change    1      0.08     0.00
#                ret_5             drawdown    1      0.08     0.00
#         vol_momentum               volume    1      0.08     0.00
#                  ofi                  ofi    1      0.08     0.00
#           vol_regime          rolling_vol    5      0.08     0.00
#         dollar_vol_z           taker_base    3      0.08     0.00
#                ret_5                  ofi    3      0.08     0.00
#        market_stress         vol_momentum    2      0.08     0.00
#                  rsi             bb_width    4      0.08     0.00
#         vol_momentum position_size_factor    1      0.08     0.00
#        market_stress         dollar_vol_z    2      0.08     0.00
#       atr_normalized          rolling_vol    4      0.08     0.00
#        market_stress         dollar_vol_z    3      0.08     0.00
#        market_stress         dollar_vol_z    1      0.08     0.00
#    trade_intensity_z        dollar_volume    2      0.08     0.00
#        volume_change          taker_quote    1      0.08     0.00
#             bb_width       taker_sell_vol    2      0.08     0.00
#              ret_raw       taker_sell_vol    3      0.08     0.00
# position_size_factor          bb_position    4      0.08     0.00
#                ret_5          bb_position    3      0.08     0.00
# position_size_factor         vol_momentum    1      0.08     0.00
#                  rsi       taker_sell_vol    1      0.08     0.00
#                ret_5          bb_position    1      0.08     0.00
#        volatility_7b       extreme_streak    2      0.08     0.00
#        trades_change       extreme_streak    1      0.08     0.00
#           taker_base           taker_base    2      0.08     0.00
#                ret_5        volume_change    5      0.07     0.00
#                  ofi               volume    2      0.07     0.00
#        volume_change       extreme_streak    4      0.07     0.00
#        market_stress       atr_normalized    2      0.07     0.00
#        trades_change position_size_factor    2      0.07     0.00
#       taker_sell_vol       taker_sell_vol    3      0.07     0.00
#        volume_change        volume_zscore    2      0.07     0.00
#        volume_change        volume_zscore    1      0.07     0.00
#    trade_intensity_z              ret_raw    2      0.07     0.00
#    trade_intensity_z              ret_raw    4      0.07     0.00
#        volume_zscore        volume_change    3      0.07     0.00
#        volatility_7b               volume    1      0.07     0.00
#         dollar_vol_z       atr_normalized    1      0.07     0.00
#    trade_intensity_z           vol_regime    1      0.07     0.00
#         dollar_vol_z             drawdown    5      0.07     0.00
#        trades_change          rolling_vol    1      0.07     0.00
#             bb_width                ret_5    1      0.07     0.00
#        trades_change         vol_momentum    2      0.07     0.00
# position_size_factor                ret_5    1      0.07     0.00
#        market_stress       taker_sell_vol    1      0.07     0.00
#        market_stress               volume    2      0.07     0.00
#    trade_intensity_z    trade_intensity_z    4      0.07     0.00
# position_size_factor          rolling_vol    5      0.07     0.00
#        volatility_7b                ret_5    1      0.07     0.00
#        market_stress          rolling_vol    5      0.07     0.00
#    trade_intensity_z          rolling_vol    4      0.07     0.00
#       taker_sell_vol          rolling_vol    1      0.07     0.00
#         vol_momentum       extreme_streak    2      0.07     0.00
#       atr_normalized          rolling_vol    3      0.07     0.00
#           vol_regime position_size_factor    5      0.07     0.00
#        volume_zscore              ret_raw    1      0.07     0.00
#        volatility_7b          rolling_vol    5      0.07     0.00
#                  ofi                  ofi    5      0.07     0.00
#         dollar_vol_z           taker_base    5      0.07     0.00
#               volume        dollar_volume    5      0.07     0.00
#        volume_zscore              ret_raw    2      0.07     0.00
#             bb_width          taker_quote    2      0.07     0.00
#    trade_intensity_z        market_stress    4      0.07     0.00
#         vol_momentum        market_stress    1      0.07     0.00
#         vol_momentum             bb_width    4      0.07     0.00
#                ret_5           taker_base    5      0.07     0.00
#        dollar_volume        dollar_volume    3      0.07     0.00
#        trades_change          taker_quote    3      0.07     0.00
#        dollar_volume         dollar_vol_z    3      0.07     0.00
#        dollar_volume         dollar_vol_z    2      0.07     0.00
# position_size_factor             bb_width    4      0.07     0.00
#    trade_intensity_z          taker_quote    4      0.07     0.00
#           taker_base               volume    2      0.07     0.00
#                  rsi             bb_width    5      0.07     0.00
#        volatility_7b         dollar_vol_z    1      0.07     0.00
#        volume_change          taker_quote    3      0.07     0.00
#          taker_quote          taker_quote    2      0.07     0.00
#           vol_regime         dollar_vol_z    1      0.07     0.00
#         vol_momentum         dollar_vol_z    3      0.07     0.00
#               volume          taker_quote    1      0.07     0.00
#    trade_intensity_z         dollar_vol_z    4      0.07     0.00
#        market_stress         dollar_vol_z    4      0.07     0.00
#        volatility_7b           taker_base    1      0.07     0.00
#        volatility_7b          bb_position    4      0.07     0.00
#       atr_normalized           taker_base    1      0.07     0.00
#               volume        vwap_distance    3      0.07     0.00
# position_size_factor         dollar_vol_z    1      0.07     0.00
#        volume_zscore        trades_change    2      0.07     0.00
#        trades_change    trade_intensity_z    1      0.07     0.00
#         dollar_vol_z    trade_intensity_z    1      0.07     0.00
#             drawdown        volatility_7b    1      0.07     0.00
#           taker_base        dollar_volume    5      0.07     0.00
#           taker_base        trades_change    3      0.07     0.00
#           vol_regime        volatility_7b    2      0.07     0.00
#           vol_regime        volatility_7b    5      0.07     0.00
#               volume               volume    2      0.07     0.00
#           taker_base        vwap_distance    1      0.07     0.00
#             bb_width        dollar_volume    2      0.06     0.01
# position_size_factor        volatility_7b    5      0.06     0.01
#           vol_regime          rolling_vol    4      0.06     0.00
#        trades_change        volatility_7b    2      0.06     0.00
# position_size_factor        market_stress    2      0.06     0.00
#        volume_zscore          taker_quote    3      0.06     0.00
#           taker_base             bb_width    2      0.06     0.00
#        trades_change          bb_position    3      0.06     0.00
#                  rsi        volatility_7b    4      0.06     0.00
#           taker_base        volume_change    1      0.06     0.01
#         dollar_vol_z        market_stress    4      0.06     0.00
#              ret_raw       taker_sell_vol    2      0.06     0.00
#             bb_width        volatility_7b    1      0.06     0.01
# position_size_factor         vol_momentum    5      0.06     0.01
#        volume_zscore        volume_change    5      0.06     0.00
#           taker_base          taker_quote    5      0.06     0.00
#               volume          taker_quote    2      0.06     0.01
#        volume_change       taker_sell_vol    4      0.06     0.00
#           taker_base             bb_width    1      0.06     0.00
#         dollar_vol_z       atr_normalized    4      0.06     0.00
#    trade_intensity_z           vol_regime    2      0.06     0.01
#               volume             bb_width    1      0.06     0.01
#           vol_regime           vol_regime    4      0.06     0.01
#        trades_change           vol_regime    2      0.06     0.01
#       taker_sell_vol           vol_regime    1      0.06     0.01
#        market_stress        volatility_7b    5      0.06     0.00
#       atr_normalized       atr_normalized    3      0.06     0.01
#          bb_position        volume_change    5      0.06     0.00
#           taker_base       taker_sell_vol    3      0.06     0.00
#        market_stress          rolling_vol    4      0.06     0.01
#              ret_raw        volume_change    2      0.06     0.00
#                ret_5                  rsi    3      0.06     0.00
#        market_stress position_size_factor    5      0.06     0.01
#    trade_intensity_z          taker_quote    2      0.06     0.00
#              ret_raw         vol_momentum    2      0.06     0.01
#             drawdown                  rsi    1      0.06     0.00
#        volatility_7b             bb_width    4      0.06     0.00
#         vol_momentum          bb_position    4      0.06     0.00
#                ret_5       taker_sell_vol    3      0.06     0.00
#        trades_change              ret_raw    1      0.06     0.01
#       taker_sell_vol       taker_sell_vol    2      0.06     0.00
#       taker_sell_vol         dollar_vol_z    4      0.06     0.00
#        volume_zscore        vwap_distance    5      0.06     0.00
#        vwap_distance       taker_sell_vol    4      0.06     0.01
#                  ofi              ret_raw    1      0.06     0.01
#       taker_sell_vol              ret_raw    3      0.06     0.01
#       taker_sell_vol         dollar_vol_z    3      0.06     0.00
#             drawdown        vwap_distance    1      0.06     0.01
#        volatility_7b         dollar_vol_z    3      0.06     0.01
#          taker_quote         dollar_vol_z    2      0.06     0.01
#                  rsi              ret_raw    4      0.06     0.00
#         dollar_vol_z           taker_base    4      0.06     0.00
#        dollar_volume         dollar_vol_z    5      0.06     0.00
#         dollar_vol_z              ret_raw    2      0.06     0.01
#           vol_regime              ret_raw    1      0.06     0.01
#        trades_change        vwap_distance    1      0.06     0.00
#          taker_quote                  ofi    2      0.06     0.00
# position_size_factor           taker_base    1      0.06     0.00
#        market_stress        trades_change    1      0.06     0.00
#       atr_normalized               volume    2      0.06     0.01
#         dollar_vol_z    trade_intensity_z    4      0.06     0.01
#             bb_width           taker_base    1      0.06     0.01
#         dollar_vol_z    trade_intensity_z    2      0.06     0.00
#        market_stress           taker_base    3      0.06     0.00
#        market_stress    trade_intensity_z    4      0.06     0.00
#        market_stress           taker_base    2      0.06     0.00
#    trade_intensity_z        trades_change    3      0.06     0.00
#           taker_base        trades_change    5      0.06     0.00
#               volume        trades_change    5      0.06     0.01
#               volume        trades_change    3      0.06     0.01
#        trades_change             drawdown    1      0.06     0.01
#                  ofi       taker_sell_vol    2      0.06     0.00
#              ret_raw                ret_5    1      0.06     0.00
#          bb_position               volume    1      0.06     0.01
# position_size_factor         dollar_vol_z    3      0.06     0.01
#           vol_regime       extreme_streak    3      0.06     0.01
#       atr_normalized           taker_base    2      0.06     0.01
#       extreme_streak position_size_factor    3      0.06     0.01
#    trade_intensity_z          bb_position    2      0.06     0.00
#          bb_position       taker_sell_vol    3      0.06     0.01
#        trades_change       extreme_streak    2      0.06     0.00
# position_size_factor       extreme_streak    2      0.06     0.00
#              ret_raw         dollar_vol_z    4      0.06     0.01
#        market_stress       extreme_streak    3      0.06     0.00
#             bb_width         dollar_vol_z    1      0.06     0.00
#        market_stress               volume    3      0.06     0.00
#        volume_zscore        vwap_distance    3      0.06     0.00
#             bb_width               volume    1      0.06     0.00
#         dollar_vol_z        vwap_distance    5      0.06     0.01
#         vol_momentum         dollar_vol_z    1      0.06     0.00
#         vol_momentum           taker_base    1      0.06     0.01
#    trade_intensity_z         dollar_vol_z    3      0.06     0.00
#        market_stress         dollar_vol_z    5      0.06     0.01
#               volume             drawdown    3      0.06     0.00
#       extreme_streak                ret_5    3      0.06     0.00
#        volume_change           taker_base    3      0.05     0.02
#              ret_raw          bb_position    1      0.05     0.02
#        trades_change        dollar_volume    1      0.05     0.01
#          taker_quote        market_stress    2      0.05     0.02
#                  ofi        vwap_distance    4      0.05     0.01
#    trade_intensity_z        dollar_volume    3      0.05     0.01
#        market_stress           taker_base    4      0.05     0.03
#        volume_change        dollar_volume    4      0.05     0.02
#        market_stress        vwap_distance    1      0.05     0.02
#        vwap_distance          bb_position    1      0.05     0.03
#         dollar_vol_z           taker_base    2      0.05     0.02
#                ret_5           taker_base    1      0.05     0.01
#        volume_zscore        dollar_volume    3      0.05     0.03
#        volume_change        market_stress    1      0.05     0.03
#                ret_5           taker_base    2      0.05     0.02
#        dollar_volume        dollar_volume    2      0.05     0.01
#          taker_quote        dollar_volume    3      0.05     0.02
#        volatility_7b        market_stress    2      0.05     0.01
#              ret_raw           taker_base    1      0.05     0.02
#           vol_regime        vwap_distance    2      0.05     0.02
#              ret_raw           taker_base    5      0.05     0.01
#        volatility_7b        market_stress    4      0.05     0.02
#         dollar_vol_z        market_stress    3      0.05     0.01
#               volume               volume    4      0.05     0.02
#       atr_normalized       atr_normalized    4      0.05     0.03
#       taker_sell_vol       taker_sell_vol    4      0.05     0.02
#         dollar_vol_z       atr_normalized    5      0.05     0.01
#         vol_momentum       atr_normalized    4      0.05     0.01
#                ret_5               volume    2      0.05     0.01
# position_size_factor               volume    3      0.05     0.03
#                  rsi               volume    4      0.05     0.03
#        volatility_7b       atr_normalized    3      0.05     0.02
#           vol_regime       taker_sell_vol    3      0.05     0.03
#       atr_normalized       atr_normalized    2      0.05     0.02
#        market_stress          rolling_vol    2      0.05     0.03
#         dollar_vol_z       atr_normalized    3      0.05     0.01
#             bb_width          rolling_vol    5      0.05     0.02
#                ret_5          rolling_vol    2      0.05     0.03
#       taker_sell_vol               volume    1      0.05     0.01
#                  ofi               volume    3      0.05     0.02
#          rolling_vol          rolling_vol    4      0.05     0.02
#             drawdown          rolling_vol    1      0.05     0.02
#              ret_raw       taker_sell_vol    4      0.05     0.01
#                  rsi       taker_sell_vol    5      0.05     0.03
#           vol_regime          rolling_vol    3      0.05     0.01
#              ret_raw               volume    5      0.05     0.01
#          rolling_vol                  ofi    3      0.05     0.03
#       taker_sell_vol        volume_zscore    5      0.05     0.02
#          taker_quote                  ofi    5      0.05     0.02
#        market_stress        volume_zscore    3      0.05     0.01
#           taker_base        vwap_distance    2      0.05     0.01
#                ret_5        volume_zscore    5      0.05     0.02
#       atr_normalized               volume    5      0.05     0.02
#                  ofi                  ofi    3      0.05     0.03
#        volume_zscore               volume    3      0.05     0.02
#        volume_zscore          rolling_vol    3      0.05     0.03
#    trade_intensity_z                  ofi    3      0.05     0.02
#        volatility_7b               volume    3      0.05     0.03
#         vol_momentum               volume    3      0.05     0.01
#              ret_raw       atr_normalized    1      0.05     0.02
#        volume_change        volume_zscore    3      0.05     0.02
#        dollar_volume        volume_zscore    2      0.05     0.02
#        dollar_volume        volume_zscore    5      0.05     0.02
#             drawdown               volume    4      0.05     0.02
#               volume       taker_sell_vol    5      0.05     0.01
#               volume       taker_sell_vol    3      0.05     0.01
#        volume_zscore                  ofi    2      0.05     0.02
#       atr_normalized                  ofi    5      0.05     0.01
# position_size_factor       atr_normalized    3      0.05     0.01
#       atr_normalized          rolling_vol    5      0.05     0.01
#             bb_width         dollar_vol_z    5      0.05     0.03
#    trade_intensity_z          bb_position    3      0.05     0.02
#        trades_change       extreme_streak    4      0.05     0.02
#       atr_normalized                ret_5    5      0.05     0.02
#       atr_normalized                ret_5    3      0.05     0.01
#        volatility_7b                ret_5    2      0.05     0.01
#        trades_change             drawdown    5      0.05     0.01
#         vol_momentum                ret_5    2      0.05     0.02
#         vol_momentum                ret_5    1      0.05     0.01
#         dollar_vol_z                ret_5    3      0.05     0.02
#           taker_base             drawdown    1      0.05     0.01
#       taker_sell_vol       extreme_streak    1      0.05     0.02
#       taker_sell_vol       extreme_streak    2      0.05     0.02
#        market_stress       extreme_streak    5      0.05     0.02
# position_size_factor                ret_5    2      0.05     0.01
#              ret_raw       extreme_streak    4      0.05     0.01
#       atr_normalized position_size_factor    5      0.05     0.02
#                ret_5             drawdown    5      0.05     0.02
#           vol_regime       extreme_streak    2      0.05     0.02
#           vol_regime          bb_position    4      0.05     0.01
#        dollar_volume       extreme_streak    1      0.05     0.01
#                  rsi position_size_factor    4      0.05     0.01
#                  rsi position_size_factor    3      0.05     0.02
#        market_stress         vol_momentum    5      0.05     0.02
#                  rsi         vol_momentum    4      0.05     0.02
#             drawdown         vol_momentum    2      0.05     0.02
#       extreme_streak         vol_momentum    3      0.05     0.01
#        market_stress position_size_factor    2      0.05     0.02
#                  ofi position_size_factor    2      0.05     0.03
#           vol_regime         vol_momentum    4      0.05     0.01
#           vol_regime         vol_momentum    5      0.05     0.01
#        market_stress              ret_raw    1      0.05     0.01
#        market_stress              ret_raw    4      0.05     0.02
# position_size_factor           vol_regime    2      0.05     0.01
#        trades_change        trades_change    5      0.05     0.01
#                ret_5         dollar_vol_z    2      0.05     0.02
#              ret_raw         dollar_vol_z    3      0.05     0.02
#          bb_position         dollar_vol_z    5      0.05     0.02
#         vol_momentum         dollar_vol_z    2      0.05     0.02
#       taker_sell_vol         dollar_vol_z    5      0.05     0.02
#          taker_quote         dollar_vol_z    4      0.05     0.02
#        dollar_volume         dollar_vol_z    1      0.05     0.01
#           taker_base              ret_raw    2      0.05     0.02
#               volume              ret_raw    5      0.05     0.01
#       atr_normalized         dollar_vol_z    1      0.05     0.03
#               volume         dollar_vol_z    4      0.05     0.02
#              ret_raw        trades_change    4      0.05     0.01
#        volume_zscore              ret_raw    4      0.05     0.01
#        volume_change        trades_change    3      0.05     0.02
#              ret_raw              ret_raw    1      0.05     0.02
#          taker_quote        trades_change    5      0.05     0.02
#       atr_normalized        trades_change    4      0.05     0.02
#               volume        trades_change    2      0.05     0.03
#             bb_width    trade_intensity_z    1      0.05     0.01
#                ret_5    trade_intensity_z    5      0.05     0.03
#              ret_raw    trade_intensity_z    5      0.05     0.01
#         dollar_vol_z    trade_intensity_z    3      0.05     0.02
#        trades_change    trade_intensity_z    5      0.05     0.03
#        dollar_volume              ret_raw    3      0.05     0.01
#    trade_intensity_z    trade_intensity_z    5      0.05     0.01
#       atr_normalized    trade_intensity_z    4      0.05     0.01
#        volatility_7b              ret_raw    1      0.05     0.02
#                  ofi             drawdown    4      0.05     0.02
#        volatility_7b                  rsi    1      0.05     0.01
# position_size_factor position_size_factor    5      0.05     0.02
#       extreme_streak        volatility_7b    3      0.05     0.01
#        market_stress          taker_quote    1      0.05     0.02
#                ret_5          taker_quote    3      0.05     0.03
#           vol_regime             bb_width    3      0.05     0.03
#        volume_change        volume_change    1      0.05     0.02
#              ret_raw                  rsi    2      0.05     0.03
#    trade_intensity_z             bb_width    4      0.05     0.03
#             bb_width                  rsi    2      0.05     0.02
#              ret_raw             bb_width    1      0.05     0.02
#                  ofi        dollar_volume    2      0.05     0.03
#        vwap_distance        dollar_volume    3      0.05     0.03
#          bb_position                  rsi    4      0.05     0.02
#    trade_intensity_z        volume_change    3      0.05     0.01
#               volume          taker_quote    5      0.05     0.01
#                  ofi             bb_width    2      0.05     0.03
#        market_stress                  rsi    2      0.05     0.02
#        market_stress             bb_width    5      0.05     0.02
#        volume_zscore        volume_change    1      0.05     0.01
#             bb_width             bb_width    3      0.05     0.01
#       atr_normalized        volatility_7b    5      0.05     0.02
#               volume             bb_width    2      0.05     0.01
#                  rsi        dollar_volume    3      0.05     0.03
#                ret_5        volume_change    3      0.05     0.01
#              ret_raw        dollar_volume    2      0.05     0.01
#                  rsi        volatility_7b    3      0.05     0.01
#                ret_5          taker_quote    2      0.04     0.04
#          taker_quote                  ofi    1      0.04     0.05
# position_size_factor             drawdown    5      0.04     0.05
# position_size_factor             drawdown    1      0.04     0.03
#          taker_quote        trades_change    3      0.04     0.04
#           vol_regime               volume    1      0.04     0.04
#             bb_width             drawdown    4      0.04     0.04
#                  rsi             bb_width    1      0.04     0.03
#        market_stress             drawdown    5      0.04     0.03
#       extreme_streak          taker_quote    4      0.04     0.04
#               volume        vwap_distance    4      0.04     0.03
#       taker_sell_vol             drawdown    4      0.04     0.03
#          rolling_vol             bb_width    1      0.04     0.04
#           vol_regime             bb_width    1      0.04     0.04
#         vol_momentum        volatility_7b    5      0.04     0.04
#    trade_intensity_z                  ofi    5      0.04     0.03
#        volatility_7b        trades_change    1      0.04     0.04
#         dollar_vol_z    trade_intensity_z    5      0.04     0.03
#       extreme_streak           vol_regime    3      0.04     0.04
#        trades_change        trades_change    3      0.04     0.03
#           vol_regime         dollar_vol_z    3      0.04     0.05
# position_size_factor         dollar_vol_z    2      0.04     0.05
#          rolling_vol           taker_base    3      0.04     0.03
#        volume_change          bb_position    4      0.04     0.04
#                ret_5         dollar_vol_z    4      0.04     0.03
#        volume_zscore           taker_base    4      0.04     0.04
#              ret_raw         dollar_vol_z    1      0.04     0.03
#              ret_raw         dollar_vol_z    2      0.04     0.04
#        dollar_volume           taker_base    3      0.04     0.03
#             bb_width        vwap_distance    4      0.04     0.04
#    trade_intensity_z         dollar_vol_z    5      0.04     0.04
#    trade_intensity_z           taker_base    5      0.04     0.03
#              ret_raw          bb_position    2      0.04     0.03
#             drawdown        dollar_volume    3      0.04     0.05
#         vol_momentum        volatility_7b    4      0.04     0.03
#        trades_change        vwap_distance    5      0.04     0.03
#        volatility_7b         dollar_vol_z    2      0.04     0.04
#          taker_quote         dollar_vol_z    3      0.04     0.04
#             drawdown        dollar_volume    4      0.04     0.03
#          taker_quote         dollar_vol_z    5      0.04     0.05
#                  rsi        dollar_volume    1      0.04     0.04
#         dollar_vol_z           taker_base    1      0.04     0.04
#       taker_sell_vol         dollar_vol_z    1      0.04     0.03
#           taker_base              ret_raw    5      0.04     0.03
#           vol_regime        dollar_volume    2      0.04     0.03
#       atr_normalized         dollar_vol_z    3      0.04     0.03
#          taker_quote          bb_position    3      0.04     0.03
#                  rsi           taker_base    4      0.04     0.04
#              ret_raw        volume_zscore    1      0.04     0.03
#        dollar_volume                  ofi    3      0.04     0.04
#                ret_5       atr_normalized    4      0.04     0.04
#       atr_normalized       extreme_streak    4      0.04     0.04
#                  ofi         vol_momentum    2      0.04     0.04
#                  ofi         vol_momentum    5      0.04     0.03
#         vol_momentum          rolling_vol    4      0.04     0.05
#             bb_width       atr_normalized    5      0.04     0.05
#                  rsi         vol_momentum    3      0.04     0.03
#         dollar_vol_z          rolling_vol    2      0.04     0.04
#              ret_raw          rolling_vol    1      0.04     0.04
# position_size_factor       atr_normalized    4      0.04     0.04
#                ret_5       atr_normalized    1      0.04     0.03
# position_size_factor          rolling_vol    4      0.04     0.05
# position_size_factor          rolling_vol    3      0.04     0.05
#    trade_intensity_z       taker_sell_vol    3      0.04     0.04
#                  ofi position_size_factor    5      0.04     0.05
#                  rsi position_size_factor    5      0.04     0.04
#        trades_change                  rsi    2      0.04     0.04
#        market_stress          rolling_vol    3      0.04     0.03
#        volatility_7b                  rsi    5      0.04     0.04
#              ret_raw       atr_normalized    3      0.04     0.03
#               volume       atr_normalized    2      0.04     0.05
#          rolling_vol           vol_regime    4      0.04     0.03
#        vwap_distance           vol_regime    1      0.04     0.05
#                  ofi           vol_regime    5      0.04     0.04
#        market_stress           vol_regime    3      0.04     0.04
#        volatility_7b       atr_normalized    4      0.04     0.05
#       atr_normalized           vol_regime    1      0.04     0.04
#    trade_intensity_z           vol_regime    3      0.04     0.04
#             drawdown       atr_normalized    2      0.04     0.05
#       atr_normalized        volume_zscore    2      0.04     0.04
#       atr_normalized       taker_sell_vol    5      0.04     0.05
#        volume_zscore                  ofi    5      0.04     0.05
#        volatility_7b        volume_change    3      0.04     0.04
#                ret_5        volume_zscore    2      0.04     0.05
#         dollar_vol_z        volatility_7b    2      0.04     0.04
#    trade_intensity_z       atr_normalized    1      0.04     0.05
#              ret_raw        volume_zscore    2      0.04     0.03
#         dollar_vol_z             drawdown    2      0.04     0.05
#       atr_normalized                ret_5    2      0.04     0.04
#        market_stress        volatility_7b    2      0.04     0.03
#         vol_momentum             drawdown    1      0.04     0.04
#           vol_regime             drawdown    2      0.04     0.03
#        volume_change                ret_5    5      0.04     0.04
#                  ofi        volatility_7b    2      0.04     0.04
#        volatility_7b             drawdown    1      0.04     0.04
# position_size_factor        market_stress    5      0.04     0.05
#        volume_change        volume_change    4      0.04     0.03
#        dollar_volume          rolling_vol    1      0.04     0.05
#        market_stress               volume    4      0.04     0.04
#        market_stress        market_stress    3      0.04     0.04
#           vol_regime        volume_change    3      0.04     0.05
#             bb_width       extreme_streak    5      0.04     0.04
#                  rsi                ret_5    4      0.04     0.03
#         vol_momentum        volume_change    5      0.04     0.05
#    trade_intensity_z        volume_change    2      0.04     0.05
#    trade_intensity_z       extreme_streak    4      0.04     0.04
#       extreme_streak       extreme_streak    5      0.04     0.05
#          taker_quote position_size_factor    3      0.04     0.05
#        volatility_7b position_size_factor    1      0.04     0.03
#         dollar_vol_z position_size_factor    2      0.04     0.04
#              ret_raw position_size_factor    2      0.04     0.04
#           taker_base           taker_base    4      0.04     0.03
# ──────────────────────────────────────────────────────────────────────
# total significant causal links: 741

# %%
# vwap_distance is the dominant sink node in the pcmci graph:
# all strong incoming links (ret_raw, rsi, bb_position, atr_normalized, volume),
# no outgoing links to return targets

# confirmed sink nodes: dollar_volume, taker_quote, taker_sell_vol,
# extreme_streak, drawdown, rolling_vol, volume

# cross-dimensional causal links visible in graph:
# volume_change (tape) → ret_raw: abnormal volume predicts return
# bb_width (technical) → ret_raw: band expansion precedes directional move
# rsi (technical) → ret_5: momentum extreme predicts multi-bar return
# atr_normalized → extreme_streak: range expansion predicts return clustering
# vol_momentum / volatility_7b / vol_regime → extreme_streak: regime drives tail persistence
# market_stress → dollar_volume / vol_momentum: composite stress drives capital flow

# construction artifacts:
# ret_raw / rsi / bb_position → vwap_distance: all price-location measures
# ofi (order flow imbalance) → taker_quote / taker_sell_vol: ofi is the normalized ratio of both
# dollar_vol_z / volume_zscore → dollar_volume: z-scores of same underlying series
# ret_5 ↔ ret_raw: multi-bar vs single-bar return overlap

# %%
# triple barrier labeling, de prado
def get_daily_vol(close: pd.Series, lookback: int = 20) -> pd.Series:
    # log returns, rolling std as volatility estimate
    log_ret = np.log(close).diff()
    return log_ret.rolling(lookback).std()

def triple_barrier_labels(
    df: pd.DataFrame,
    pt_sl: list = [2.0, 2.0],
    max_hold: int = 20,
    min_ret: float = 0.001,
) -> pd.DataFrame:
    # pt_sl[0] = upper barrier multiplier (profit target)
    # pt_sl[1] = lower barrier multiplier (stop loss)
    # asymmetric by design: reward > risk is intentional
    close = df['close']
    vol   = get_daily_vol(close, lookback=20)

    # validate multipliers against actual single-bar breach rates
    returns    = close.pct_change()
    normalized = (returns.abs() / vol).dropna()
    print("multiplier calibration check:")
    print(f"  > {pt_sl[0]}x vol (pt): {(normalized > pt_sl[0]).mean():.1%} of bars breach in single step")
    print(f"  > {pt_sl[1]}x vol (sl): {(normalized > pt_sl[1]).mean():.1%} of bars breach in single step")
    print("─" * 70)

    labels = []
    for i in range(len(close) - max_hold):
        t0    = close.index[i]
        price = close.iloc[i]
        v     = vol.iloc[i]

        if pd.isna(v) or v < min_ret:
            labels.append({'timestamp': t0, 'label': np.nan, 'ret': np.nan,
                           'barrier': 'skip', 'vol_at_entry': np.nan})
            continue

        upper = price * (1 + pt_sl[0] * v)
        lower = price * (1 - pt_sl[1] * v)
        path  = close.iloc[i + 1 : i + 1 + max_hold]
        label = 0
        hit   = 'vertical'

        for j, p in enumerate(path):
            if p >= upper:
                label, hit = 1, 'upper'
                break
            elif p <= lower:
                label, hit = -1, 'lower'
                break

        ret = (path.iloc[-1] - price) / price if hit == 'vertical' \
              else (path.iloc[j] - price) / price

        labels.append({'timestamp': t0, 'label': label, 'ret': ret,
                       'barrier': hit, 'vol_at_entry': v})

    return pd.DataFrame(labels).set_index('timestamp')


labels = triple_barrier_labels(df, pt_sl=[1.5, 1.5], max_hold=20)
df     = df.join(labels[['label', 'ret', 'barrier', 'vol_at_entry']], how='left')
df.dropna(subset=['label'], inplace=True)
df['label'] = df['label'].astype(int)

# regime dependent label check
df['vol_regime_check'] = pd.cut(
    df['vol_at_entry'],
    bins=[0, df['vol_at_entry'].quantile(0.33),
             df['vol_at_entry'].quantile(0.67), np.inf],
    labels=['low', 'mid', 'high']
)
print("label distribution per vol regime (should be stable):")
print(df.groupby('vol_regime_check')['label'].value_counts(normalize=True).unstack().round(3))
print("─" * 70)

print(f"total labeled bars: {len(df)}")
print(f"\nlabel distribution:")
print(df['label'].value_counts().sort_index())
print(f"\nbarrier hit distribution:")
print(df['barrier'].value_counts())
print("─" * 70)

total = len(df)
for lbl, name in [(-1, 'short/stop'), (0, 'timeout'), (1, 'profit')]:
    n = (df['label'] == lbl).sum()
    print(f"  {name:12s}: {n:4d}  ({n/total*100:.1f}%)")
# Out:
# multiplier calibration check:
#   > 1.5x vol (pt): 14.0% of bars breach in single step
#   > 1.5x vol (sl): 14.0% of bars breach in single step
# ──────────────────────────────────────────────────────────────────────
# label distribution per vol regime (should be stable):
# label                -1      0      1
# vol_regime_check
# low               0.474  0.000  0.526
# mid               0.528  0.000  0.472
# high              0.363  0.035  0.602
# ──────────────────────────────────────────────────────────────────────
# total labeled bars: 2326
#
# label distribution:
# label
# -1    1060
#  0      27
#  1    1239
# Name: count, dtype: int64
#
# barrier hit distribution:
# barrier
# upper       1239
# lower       1060
# vertical      27
# Name: count, dtype: int64
# ──────────────────────────────────────────────────────────────────────
#   short/stop  : 1060  (45.6%)
#   timeout     :   27  (1.2%)
#   profit      : 1239  (53.3%)

# %%
# test if sl changes label balance meaningfully
for sl in [1.0, 1.5, 2.0]:
    labels_test = triple_barrier_labels(df, pt_sl=[1.5, sl], max_hold=20)
    dist = labels_test['label'].value_counts(normalize=True)
    print(f"sl={sl}x:  upper={dist.get(1, 0):.1%}  lower={dist.get(-1, 0):.1%}  vertical={dist.get(0, 0):.1%}")
# Out:
# multiplier calibration check:
#   > 1.5x vol (pt): 14.0% of bars breach in single step
#   > 1.0x vol (sl): 31.6% of bars breach in single step
# ──────────────────────────────────────────────────────────────────────
# sl=1.0x:  upper=47.1%  lower=52.6%  vertical=0.3%
# multiplier calibration check:
#   > 1.5x vol (pt): 14.0% of bars breach in single step
#   > 1.5x vol (sl): 14.0% of bars breach in single step
# ──────────────────────────────────────────────────────────────────────
# sl=1.5x:  upper=53.4%  lower=45.6%  vertical=1.0%
# multiplier calibration check:
#   > 1.5x vol (pt): 14.0% of bars breach in single step
#   > 2.0x vol (sl): 5.2% of bars breach in single step
# ──────────────────────────────────────────────────────────────────────
# sl=2.0x:  upper=57.0%  lower=40.6%  vertical=2.4%

# %%
# sl=1.0x rejected: 31.6% single-step breach rate makes labels unreliable
# sl=1.5x borderline: breach rate ok, but near-even win/loss split
# sl=2.0x selected: lowest breach rate (5.2%), clearest upward label bias (57% upper)

# %%
# drop old label columns if they exist from previous run
cols_to_drop = ['label', 'ret', 'barrier', 'vol_at_entry', 'vol_regime_check']
df.drop(columns=[c for c in cols_to_drop if c in df.columns], inplace=True)

# recalibrate triple barrier with adjusted multipliers
# make sl symmetric to pt
# this gives price more room and forces more vertical barrier hits
labels = triple_barrier_labels(df, pt_sl=[2.5, 2.5], max_hold=20)
df = df.join(labels[['label', 'ret', 'barrier', 'vol_at_entry']], how='left')
df.dropna(subset=['label'], inplace=True)
df['label'] = df['label'].astype(int)

# vol regime stability check
df['vol_regime_check'] = pd.cut(
    df['vol_at_entry'],
    bins=[0, df['vol_at_entry'].quantile(0.33),
             df['vol_at_entry'].quantile(0.67), np.inf],
    labels=['low', 'mid', 'high']
)
regime_dist = df.groupby('vol_regime_check')['label'].value_counts(normalize=True).unstack().round(3)
print("label distribution per vol regime (target: <5pp spread across regimes):")
print(regime_dist)
print("─" * 70)

total = len(df)
print(f"total labeled bars: {total}\n")
print("barrier hit distribution:")
print(df['barrier'].value_counts())
print()

for lbl, name in [(-1, 'short/stop'), (0, 'timeout'), (1, 'profit')]:
    n = (df['label'] == lbl).sum()
    print(f"  {name:12s}: {n:4d}  ({n/total*100:.1f}%)")

print("─" * 70)

timeout_pct = (df['label'] == 0).sum() / total
if timeout_pct < 0.05:
    print(f"warning: vertical barrier only {timeout_pct:.1%}, consider increasing max_hold or pt")
elif timeout_pct > 0.20:
    print(f"warning: too many timeouts {timeout_pct:.1%}, barriers may be too wide")
else:
    print(f"ok: vertical barrier at {timeout_pct:.1%}")

if 1 in regime_dist.columns:
    spread = regime_dist[1].max() - regime_dist[1].min()
    if spread > 0.05:
        print(f"warning: regime spread {spread:.3f} > 0.05, upward bias still present")
    else:
        print(f"ok: regime spread {spread:.3f}")
# Out:
# multiplier calibration check:
#   > 2.5x vol (pt): 1.4% of bars breach in single step
#   > 2.5x vol (sl): 1.4% of bars breach in single step
# ──────────────────────────────────────────────────────────────────────
# label distribution per vol regime (target: <5pp spread across regimes):
# label                -1      0      1
# vol_regime_check
# low               0.453  0.045  0.502
# mid               0.539  0.037  0.424
# high              0.290  0.252  0.458
# ──────────────────────────────────────────────────────────────────────
# total labeled bars: 2286
#
# barrier hit distribution:
# barrier
# upper       1054
# lower        979
# vertical     253
# Name: count, dtype: int64
#
#   short/stop  :  979  (42.8%)
#   timeout     :  253  (11.1%)
#   profit      : 1054  (46.1%)
# ──────────────────────────────────────────────────────────────────────
# ok: vertical barrier at 11.1%
# warning: regime spread 0.078 > 0.05, upward bias still present

# %%
# only 1.4% of bars cross a barrier in a single move (< 5% is solid)
# low volatility slight upwards bias, moderat time outs
# mid volatility short biased
# high volatility, more timeouts 25% → important, fewer stops than expected 29.2%
# regime spread 0.078 > 0.05 threshold: label distribution varies across vol regimes
# about 5% of trades end due to time limit

# %%
# drop timeout bars, remap stops to 0 and profits to 1
df = df[df['label'] != 0].copy()
df['label'] = df['label'].map({-1: 0, 1: 1})

print(f"bars after label drop: {len(df)}")
print(df['label'].value_counts().sort_index())
print(f"balance: {df['label'].mean():.3f}")
# Out:
# bars after label drop: 2033
# label
# 0     979
# 1    1054
# Name: count, dtype: int64
# balance: 0.518

# %%
# use triple barrier labels as target
model_features = [f for f in stationary_features if f not in
                  ['label', 'ret', 'barrier', 'return', 'rolling_vol']]
X = df[model_features]
y = df['label']

# purged split with embargo: drop max_hold bars at boundary to prevent leakage
max_hold  = 20
split_idx = int(len(X) * 0.7)

X_train, y_train = X.iloc[:split_idx],              y.iloc[:split_idx]
X_test,  y_test  = X.iloc[split_idx + max_hold:],   y.iloc[split_idx + max_hold:]

print(f"train: {len(X_train)} | test: {len(X_test)}")
print(f"embargo: {max_hold} bars removed at boundary")
print(f"target balance (train): {y_train.mean():.3f}")
print("─" * 70)

rf = RandomForestClassifier(
    n_estimators=500,
    max_depth=4,
    min_samples_leaf=20,
    max_features='sqrt',
    class_weight='balanced',
    random_state=42,
    n_jobs=-1,
)
rf.fit(X_train, y_train)
print(f"train accuracy: {rf.score(X_train, y_train):.3f}")
print(f"test accuracy:  {rf.score(X_test, y_test):.3f}")
print("─" * 70)

# mdi on training data
mdi = pd.Series(rf.feature_importances_, index=model_features).sort_values(ascending=False)
print("mdi feature importance:")
print(mdi.round(4))
print("─" * 70)

# mda on test data
perm = permutation_importance(rf, X_test, y_test, n_repeats=30, random_state=42, n_jobs=-1)
mda  = pd.Series(perm.importances_mean, index=model_features).sort_values(ascending=False)
print("mda feature importance:")
print(mda.round(4))
print("─" * 70)

combined = ((mdi.rank(ascending=False) + mda.rank(ascending=False)) / 2).sort_values()
print("combined ranking (lower = more important):")
print(combined.round(1))

# pcmci-confirmed: sources that causally drive at least one target at lag=1
pcmci_confirmed = set(
    edge_df_pcmci[edge_df_pcmci['lag'] == 1]['source'].unique()
)

# visualization
rcParams['font.family'] = 'DejaVu Sans'
rcParams['font.size']   = 12
fig, axes = plt.subplots(1, 2, figsize=(16, 7))
for ax, values, title in [
    (axes[0], mdi.sort_values(), 'mdi (mean decrease impurity)'),
    (axes[1], mda.sort_values(), 'mda (permutation importance)'),
]:
    colors = ['#FFB6C1' if f in pcmci_confirmed else '#c9a0dc'
              for f in values.index]
    ax.barh(range(len(values)), values.values,
            color=colors, alpha=0.85, edgecolor='none')
    ax.set_yticks(range(len(values)))
    ax.set_yticklabels(values.index, fontsize=9, color='#808079')
    ax.set_title(title, fontsize=12, pad=12)
    ax.grid(True, color='gray', linestyle=(0, (10, 10)),
            linewidth=0.5, alpha=0.6)
    for spine in ax.spines.values():
        spine.set_visible(False)
    ax.tick_params(colors='#808079')

legend = [
    mpatches.Patch(color='#FFB6C1', label='pcmci causal driver (lag=1)'),
    mpatches.Patch(color='#c9a0dc', label='not confirmed by pcmci'),
]
axes[1].legend(handles=legend, fontsize=9, framealpha=0.8)
plt.suptitle(f'feature importance  |  test acc: {rf.score(X_test, y_test):.3f}',
             fontsize=13)
plt.tight_layout()
plt.savefig('results/random_forest.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# train: 1423 | test: 590
# embargo: 20 bars removed at boundary
# target balance (train): 0.550
# ──────────────────────────────────────────────────────────────────────
# train accuracy: 0.701
# test accuracy:  0.573
# ──────────────────────────────────────────────────────────────────────
# mdi feature importance:
# volume                  0.1443
# bb_width                0.1295
# taker_base              0.1134
# drawdown                0.1065
# atr_normalized          0.0766
# rsi                     0.0695
# volatility_7b           0.0435
# vwap_distance           0.0409
# deep_drawdown           0.0277
# taker_sell_vol          0.0255
# vol_momentum            0.0251
# position_size_factor    0.0204
# bb_position             0.0194
# ofi                     0.0176
# dollar_volume           0.0163
# trade_intensity_z       0.0158
# taker_quote             0.0152
# volume_zscore           0.0151
# ret_5                   0.0146
# dollar_vol_z            0.0133
# volume_change           0.0127
# trades_change           0.0124
# ret_raw                 0.0115
# market_stress           0.0042
# vol_regime              0.0036
# vol_persistence         0.0017
# extreme_streak          0.0015
# vol_regime_change       0.0008
# var_breach_95           0.0006
# tail_risk_signal        0.0004
# upside_momentum         0.0003
# vol_expansion           0.0000
# dtype: float64
# ──────────────────────────────────────────────────────────────────────
# mda feature importance:
# volume                  0.0118
# atr_normalized          0.0099
# taker_base              0.0072
# deep_drawdown           0.0057
# drawdown                0.0038
# bb_width                0.0033
# trade_intensity_z       0.0023
# position_size_factor    0.0009
# vol_regime_change       0.0005
# extreme_streak          0.0002
# vol_expansion           0.0000
# upside_momentum         0.0000
# taker_quote            -0.0002
# var_breach_95          -0.0004
# vol_persistence        -0.0006
# bb_position            -0.0007
# trades_change          -0.0014
# market_stress          -0.0018
# tail_risk_signal       -0.0018
# vol_momentum           -0.0020
# dollar_vol_z           -0.0020
# vol_regime             -0.0021
# volatility_7b          -0.0022
# ret_5                  -0.0024
# taker_sell_vol         -0.0025
# dollar_volume          -0.0027
# volume_change          -0.0028
# vwap_distance          -0.0033
# ret_raw                -0.0037
# volume_zscore          -0.0056
# ofi                    -0.0057
# rsi                    -0.0124
# dtype: float64
# ──────────────────────────────────────────────────────────────────────
# combined ranking (lower = more important):
# volume                   1.0
# taker_base               3.0
# atr_normalized           3.5
# bb_width                 4.0
# drawdown                 4.5
# deep_drawdown            6.5
# position_size_factor    10.0
# trade_intensity_z       11.5
# bb_position             14.5
# volatility_7b           15.0
# taker_quote             15.0
# vol_momentum            15.5
# taker_sell_vol          17.5
# vwap_distance           18.0
# vol_regime_change       18.5
# extreme_streak          18.5
# rsi                     19.0
# trades_change           19.5
# vol_persistence         20.5
# dollar_volume           20.5
# dollar_vol_z            20.5
# market_stress           21.0
# upside_momentum         21.2
# var_breach_95           21.5
# ret_5                   21.5
# vol_expansion           21.8
# ofi                     22.5
# vol_regime              23.5
# volume_zscore           24.0
# volume_change           24.0
# tail_risk_signal        24.5
# ret_raw                 26.0
# dtype: float64

# %%
# train acc 0.701 vs test acc 0.573, 13pp gap indicates overfitting
# top features by combined rank: volume, taker_base, atr_normalized, bb_width, drawdown
# candidates for removal (low mdi + negative mda): rsi, ret_raw, vol_expansion, tail_risk_signal
# vol_regime rank 23.5: regime leakage not actively exploited by model

# %%
# drop if: mda negative or bottom 30% in combined ranking
mda_negative  = mda[mda < 0].index.tolist()
combined_weak = combined[combined > combined.quantile(0.70)].index.tolist()
drop_features  = list(set(mda_negative + combined_weak))

print(f"dropping {len(drop_features)} noise features:")
print(f"  mda negative:  {mda_negative}")
print(f"  combined weak: {[f for f in combined_weak if f not in mda_negative]}")

final_features = [f for f in model_features if f not in drop_features]
print(f"\nfinal feature set ({len(final_features)}): {final_features}")
print("─" * 70)

X_train_c = X_train[final_features]
X_test_c  = X_test[final_features]

rf2 = RandomForestClassifier(
    n_estimators=500,
    max_depth=4,
    min_samples_leaf=20,
    max_features='sqrt',
    class_weight='balanced',
    random_state=42,
    n_jobs=-1,
)
rf2.fit(X_train_c, y_train)

print(f"train accuracy: {rf2.score(X_train_c, y_train):.3f}")
print(f"test accuracy:  {rf2.score(X_test_c, y_test):.3f}")
print("─" * 70)

# check if test accuracy improved over rf1
delta = rf2.score(X_test_c, y_test) - rf.score(X_test, y_test)
print(f"accuracy delta vs rf1: {delta:+.3f}")
# Out:
# dropping 22 noise features:
#   mda negative:  ['taker_quote', 'var_breach_95', 'vol_persistence', 'bb_position', 'trades_change', 'market_stress', 'tail_risk_signal', 'vol_momentum', 'dollar_vol_z', 'vol_regime', 'volatility_7b', 'ret_5', 'taker_sell_vol', 'dollar_volume', 'volume_change', 'vwap_distance', 'ret_raw', 'volume_zscore', 'ofi', 'rsi']
#   combined weak: ['upside_momentum', 'vol_expansion']
#
# final feature set (10): ['bb_width', 'position_size_factor', 'trade_intensity_z', 'drawdown', 'extreme_streak', 'atr_normalized', 'volume', 'taker_base', 'vol_regime_change', 'deep_drawdown']
# ──────────────────────────────────────────────────────────────────────
# train accuracy: 0.693
# test accuracy:  0.573
# ──────────────────────────────────────────────────────────────────────
# accuracy delta vs rf1: +0.000

# %%
# dropped 22 noise features: train 0.693 / test 0.573
# test accuracy unchanged, removed features were noise

# %%
# purged k-fold cross validation (de prado)
# problem: rolling windows cause leakage at fold boundaries
# solution: purge training samples whose window overlaps with test period
# embargo: remove n bars after each test fold (autocorrelation buffer)
embargo_pct = max_hold / len(df)  # ~0.025

class PurgedKFold:
    def __init__(self, n_splits=5, embargo_pct=embargo_pct): 
        self.n_splits    = n_splits
        self.embargo_pct = embargo_pct

    def split(self, X, y=None, groups=None):
        n         = len(X)
        embargo_n = max(1, int(n * self.embargo_pct))
        indices   = np.arange(n)
        fold_size = n // self.n_splits
        for fold in range(self.n_splits):
            test_start = fold * fold_size
            test_end   = test_start + fold_size if fold < self.n_splits - 1 else n
            test_idx   = indices[test_start:test_end]
            purge_start = max(0, test_start - max_hold)
            train_idx   = np.concatenate([
                indices[:purge_start],
                indices[min(test_end + embargo_n, n):]
            ])
            if len(train_idx) == 0 or len(test_idx) == 0:
                continue
            yield train_idx, test_idx

    def get_n_splits(self, X=None, y=None, groups=None):
        return self.n_splits

def purged_cv(model, X, y, n_splits=5, embargo_pct=embargo_pct):  # <- hier
    pkf     = PurgedKFold(n_splits=n_splits, embargo_pct=embargo_pct)
    results = []
    for fold, (train_idx, test_idx) in enumerate(pkf.split(X)):
        X_tr, X_te = X.iloc[train_idx], X.iloc[test_idx]
        y_tr, y_te = y.iloc[train_idx], y.iloc[test_idx]
        model.fit(X_tr, y_tr)
        prob = model.predict_proba(X_te)[:, 1]
        pred = model.predict(X_te)
        results.append({
            'fold':       fold + 1,
            'train_size': len(X_tr),
            'test_size':  len(X_te),
            'accuracy':   accuracy_score(y_te, pred),
            'auc':        roc_auc_score(y_te, prob),
            'log_loss':   log_loss(y_te, prob),
        })
    return pd.DataFrame(results)

X_cv = df[final_features]
y_cv = df['label']
print(f"total bars: {len(X_cv)} | features: {len(final_features)}")
print(f"embargo_pct: {embargo_pct:.4f} ({max_hold} bars)")
print(f"target balance: {y_cv.mean():.3f}")
print("─" * 70)

rf_cv = RandomForestClassifier(
    n_estimators=500,
    max_depth=3,
    min_samples_leaf=30,
    max_features='sqrt',
    class_weight='balanced',
    random_state=42,
    n_jobs=-1,
)
cv_results = purged_cv(rf_cv, X_cv, y_cv, n_splits=5, embargo_pct=embargo_pct)
print("purged k-fold results per fold:")
print(cv_results.to_string(index=False))
print("─" * 70)

for metric in ['accuracy', 'auc', 'log_loss']:
    mean = cv_results[metric].mean()
    std  = cv_results[metric].std()
    print(f"  {metric:<12} mean={mean:.4f}  std={std:.4f}")
print("─" * 70)

# naive comparison with correct embargo at boundary
split_idx  = int(len(X_cv) * 0.7)
rf_cv.fit(X_cv.iloc[:split_idx], y_cv.iloc[:split_idx])
naive_acc  = accuracy_score(y_cv.iloc[split_idx + max_hold:], rf_cv.predict(X_cv.iloc[split_idx + max_hold:]))
purged_acc = cv_results['accuracy'].mean()
print(f"naive 70/30 test accuracy:  {naive_acc:.4f}")
print(f"purged cv mean accuracy:    {purged_acc:.4f}")
print(f"leakage inflation estimate: {naive_acc - purged_acc:+.4f}")

auc_mean = cv_results['auc'].mean()
print("─" * 70)
if auc_mean > 0.55:
    print(f"auc={auc_mean:.4f} → predictive edge")
elif auc_mean > 0.52:
    print(f"auc={auc_mean:.4f} → weak edge")
else:
    print(f"auc={auc_mean:.4f} → no reliable edge")
# Out:
# total bars: 2033 | features: 10
# embargo_pct: 0.0098 (20 bars)
# target balance: 0.518
# ──────────────────────────────────────────────────────────────────────
# purged k-fold results per fold:
#  fold  train_size  test_size  accuracy      auc  log_loss
#     1        1607        406  0.532020 0.565914  0.679757
#     2        1587        406  0.556650 0.625704  0.671583
#     3        1587        406  0.524631 0.595273  0.689933
#     4        1587        406  0.539409 0.609726  0.731771
#     5        1604        409  0.577017 0.584026  0.710124
# ──────────────────────────────────────────────────────────────────────
#   accuracy     mean=0.5459  std=0.0210
#   auc          mean=0.5961  std=0.0230
#   log_loss     mean=0.6966  std=0.0244
# ──────────────────────────────────────────────────────────────────────
# naive 70/30 test accuracy:  0.5729
# purged cv mean accuracy:    0.5459
# leakage inflation estimate: +0.0269
# ──────────────────────────────────────────────────────────────────────
# auc=0.5961 → predictive edge

# %%
# changed max depth and leafes to get better log loss
# max_depth=3, min_samples_leaf=30: acc -0.005, auc +0.009, log_loss -0.007
# slightly lower accuracy, better probability calibration
# proceed to backtest with current params

# %%
# regime-change prediction
# target: predict vol_regime of NEXT bar (0=low, 1=med, 2=high)
regime_features = [
    # mda-validated from main model
    'bb_position', 'extreme_streak', 'atr_normalized',
    'vol_persistence','tail_risk_signal',
    # regime-specific additions
    'bb_width', 'volatility_7b', 'volume_zscore', 
    "dollar_vol_z", 'market_stress',
]

df['regime_next'] = df['vol_regime'].shift(-1)
df_reg = df[regime_features + ['regime_next', 'vol_regime']].dropna()
X_reg  = df_reg[regime_features]
y_reg  = df_reg['regime_next'].astype(int)
print(f"total bars: {len(X_reg)}")
print(f"regime distribution:\n{y_reg.value_counts(normalize=True).round(3)}")
print("─" * 70)

pkf = PurgedKFold(n_splits=5, embargo_pct=embargo_pct)
rf_reg = RandomForestClassifier(
    n_estimators=500,
    max_depth=5,
    min_samples_leaf=15,
    max_features='sqrt',
    class_weight='balanced',
    random_state=42,
    n_jobs=-1,
)

# nan-init: purged/embargoed bars stay nan, not silently assigned to class 0
probs        = np.full((len(X_reg), 3), np.nan)
fold_results = []
fold_importances = []

for fold, (train_idx, test_idx) in enumerate(pkf.split(X_reg)):
    X_tr, X_te = X_reg.iloc[train_idx], X_reg.iloc[test_idx]
    y_tr, y_te = y_reg.iloc[train_idx], y_reg.iloc[test_idx]
    rf_reg.fit(X_tr, y_tr)
    prob = rf_reg.predict_proba(X_te)
    pred = rf_reg.predict(X_te)
    probs[test_idx] = prob
    fold_importances.append(rf_reg.feature_importances_)
    acc    = (pred == y_te.values).mean()
    y_bin  = label_binarize(y_te, classes=[0, 1, 2])
    auc_per_class = {}
    for i, label in enumerate(['low', 'med', 'high']):
        auc_per_class[f'auc_{label}'] = (
            roc_auc_score(y_bin[:, i], prob[:, i]) if y_bin[:, i].sum() > 0 else np.nan
        )
    fold_results.append({'fold': fold + 1, 'accuracy': acc, **auc_per_class})

df_reg['prob_low']    = probs[:, 0]
df_reg['prob_med']    = probs[:, 1]
df_reg['prob_high']   = probs[:, 2]
df_reg['pred_regime'] = np.where(
    np.isnan(probs[:, 0]), np.nan, np.argmax(probs, axis=1)
)

res = pd.DataFrame(fold_results)
print("purged cv regime prediction:")
print(res.to_string(index=False))
print("─" * 70)

baseline_acc = (y_reg == y_reg.mode()[0]).mean()
model_acc    = res['accuracy'].mean()
print(f"baseline accuracy (majority class): {baseline_acc:.4f}")
print(f"model accuracy (purged cv mean):    {model_acc:.4f}")
print(f"lift over baseline:                 {model_acc - baseline_acc:+.4f}")
print("─" * 70)

for col in ['auc_low', 'auc_med', 'auc_high']:
    print(f"  {col}: mean={res[col].mean():.4f} ± {res[col].std():.4f}")
print("─" * 70)

print("actual regime transition matrix (row=current, col=next):")
trans = pd.crosstab(df_reg['vol_regime'].astype(int),
                    df_reg['regime_next'].astype(int),
                    normalize='index').round(3)
trans.index   = ['low', 'med', 'high']
trans.columns = ['→low', '→med', '→high']
print(trans)
print("─" * 70)

# mdi averaged across all folds, not just last
imp = pd.Series(
    np.mean(fold_importances, axis=0), index=regime_features
).sort_values(ascending=False)
print("feature importance for regime prediction (mdi, mean across folds):")
print(imp.round(4))
# Out:
# total bars: 2032
# regime distribution:
# regime_next
# 1    0.438
# 2    0.286
# 0    0.277
# Name: proportion, dtype: float64
# ──────────────────────────────────────────────────────────────────────
# purged cv regime prediction:
#  fold  accuracy  auc_low  auc_med  auc_high
#     1  0.596059 0.852004 0.700865  0.907580
#     2  0.655172 0.849202 0.715252  0.925398
#     3  0.613300 0.838945 0.739320  0.908348
#     4  0.637931 0.889143 0.746465  0.921856
#     5  0.659314 0.866944 0.712971  0.899899
# ──────────────────────────────────────────────────────────────────────
# baseline accuracy (majority class): 0.4375
# model accuracy (purged cv mean):    0.6324
# lift over baseline:                 +0.1949
# ──────────────────────────────────────────────────────────────────────
#   auc_low: mean=0.8592 ± 0.0195
#   auc_med: mean=0.7230 ± 0.0192
#   auc_high: mean=0.9126 ± 0.0107
# ──────────────────────────────────────────────────────────────────────
# actual regime transition matrix (row=current, col=next):
#        →low   →med  →high
# low   0.721  0.262  0.018
# med   0.169  0.672  0.160
# high  0.012  0.250  0.738
# ──────────────────────────────────────────────────────────────────────
# feature importance for regime prediction (mdi, mean across folds):
# market_stress       0.3735
# volatility_7b       0.2901
# bb_position         0.1075
# vol_persistence     0.1000
# extreme_streak      0.0329
# dollar_vol_z        0.0254
# volume_zscore       0.0236
# bb_width            0.0208
# atr_normalized      0.0182
# tail_risk_signal    0.0079
# dtype: float64

# %%
# regime model: acc=0.632, lift=+0.195 over baseline, strong performance
# auc_high=0.913, auc_low=0.859: extreme regimes predicted reliably
# auc_med=0.723: transition regime harder to predict
# regimes are persistent (72-74% self-transition), model exploits autocorrelation

# %%
# how many bars have no oos prediction?
print(f"bars with zero probs: {(probs.sum(axis=1) == 0).sum()}")
print(f"total bars: {len(probs)}")
# Out:
# bars with zero probs: 0
# total bars: 2032

# %%
# train/test is sequential, last fold is the most recent data.
# check if performance degrades in the most recent fold specifically.
print(res[['fold', 'accuracy', 'auc_low', 'auc_med', 'auc_high']])
# Out:
#    fold  accuracy   auc_low   auc_med  auc_high
# 0     1  0.596059  0.852004  0.700865  0.907580
# 1     2  0.655172  0.849202  0.715252  0.925398
# 2     3  0.613300  0.838945  0.739320  0.908348
# 3     4  0.637931  0.889143  0.746465  0.921856
# 4     5  0.659314  0.866944  0.712971  0.899899

# %%
# visualizing regime change catching ability from model

window_start = 400
window_end   = 700

mask   = ~np.isnan(df_reg['pred_regime'])
df_vis = df_reg[mask].reset_index(drop=True).iloc[window_start:window_end]
x      = np.arange(len(df_vis))

fig, axes = plt.subplots(3, 1, figsize=(16, 12),
                          gridspec_kw={'height_ratios': [2, 2, 1]})
fig.patch.set_facecolor('white')

regime_colors = {0: '#a8c8e8', 1: '#c9a0dc', 2: '#FFB6C1'}
regime_labels = {0: 'low', 1: 'medium', 2: 'high'}

def fill_regime_blocks(ax, x, regime_values, regime_colors, alpha=0.3):
    # draw one axvspan per contiguous regime block instead of per bar
    i = 0
    while i < len(regime_values):
        current = int(regime_values[i])
        j = i
        while j < len(regime_values) and int(regime_values[j]) == current:
            j += 1
        ax.axvspan(x[i], x[j-1] + 1, color=regime_colors[current], alpha=alpha)
        i = j

# actual regime
ax = axes[0]
ax.set_facecolor('white')
actual = df_vis['vol_regime'].values
fill_regime_blocks(ax, x, actual, regime_colors)
ax.step(x, actual, where='post', color='#404040', linewidth=1.5)
ax.set_yticks([0, 1, 2])
ax.set_yticklabels(['low', 'med', 'high'])
ax.set_xlim(0, len(x))
ax.set_title(f'actual regime (bars {window_start}–{window_end})',
             fontsize=11, color='#404040')
for spine in ax.spines.values():
    spine.set_visible(False)
legend_patches = [mpatches.Patch(color=c, alpha=0.5, label=regime_labels[k])
                  for k, c in regime_colors.items()]
ax.legend(handles=legend_patches, loc='upper right', fontsize=9, framealpha=0.8)

# predicted regime + mismatch
ax2 = axes[1]
ax2.set_facecolor('white')
pred = df_vis['pred_regime'].values
fill_regime_blocks(ax2, x, pred, regime_colors)
ax2.step(x, pred, where='post', color='#e05555', linewidth=1.5)
mismatch = actual != pred
ax2.fill_between(x, -0.3, 2.3, where=mismatch, step='post',
                 color='#e05555', alpha=0.12, label='mismatch')
ax2.set_yticks([0, 1, 2])
ax2.set_yticklabels(['low', 'med', 'high'])
ax2.set_xlim(0, len(x))
ax2.set_title('predicted regime + mismatch (red shading)', fontsize=11, color='#404040')
for spine in ax2.spines.values():
    spine.set_visible(False)

# confidence per class
ax3 = axes[2]
ax3.set_facecolor('white')
ax3.plot(x, df_vis['prob_low'],  color='#a8c8e8', linewidth=1.2, label='p(low)')
ax3.plot(x, df_vis['prob_med'],  color='#c9a0dc', linewidth=1.2, label='p(med)')
ax3.plot(x, df_vis['prob_high'], color='#FFB6C1', linewidth=1.2, label='p(high)')
ax3.axhline(0.5, color='#aaaaaa', linewidth=0.8, linestyle='--')
ax3.set_xlim(0, len(x))
ax3.set_ylim(0, 1)
ax3.set_ylabel('probability')
ax3.set_xlabel('bar index (within window)')
ax3.set_title('model confidence per regime class', fontsize=11, color='#404040')
ax3.legend(loc='upper right', fontsize=9, framealpha=0.8)
for spine in ax3.spines.values():
    spine.set_visible(False)

plt.tight_layout(h_pad=1.5)
plt.savefig('results/regime_detection.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# merge regime probabilities back into main df by index
df = df.join(df_reg[['prob_low', 'prob_med', 'prob_high']], how='left')

regime_conditioned_features = final_features + ['prob_low', 'prob_med', 'prob_high']

# drop rows where regime probs are nan (purged/embargoed bars)
df_rc = df[regime_conditioned_features + ['label']].dropna()
X_rc  = df_rc[regime_conditioned_features]
y_rc  = df_rc['label']

print(f"total bars: {len(X_rc)} | features: {len(regime_conditioned_features)}")
print(f"target balance: {y_rc.mean():.3f}")
print("─" * 70)

rf_rc = RandomForestClassifier(
    n_estimators=500,
    max_depth=4,
    min_samples_leaf=20,
    max_features='sqrt',
    class_weight='balanced',
    random_state=42,
    n_jobs=-1,
)

cv_results_rc = purged_cv(rf_rc, X_rc, y_rc, n_splits=5, embargo_pct=embargo_pct)
print("purged k-fold results (regime-conditioned):")
print(cv_results_rc.to_string(index=False))
print("─" * 70)

for metric in ['accuracy', 'auc', 'log_loss']:
    mean_rc  = cv_results_rc[metric].mean()
    mean_old = cv_results[metric].mean()
    delta    = mean_rc - mean_old
    print(f"  {metric:<12} mean={mean_rc:.4f}  delta vs baseline: {delta:+.4f}")

print("─" * 70)
auc_rc = cv_results_rc['auc'].mean()
auc_base = cv_results['auc'].mean()
if auc_rc > auc_base + 0.01:
    print(f"auc={auc_rc:.4f} → regime conditioning improved edge (+{auc_rc - auc_base:.4f})")
elif auc_rc < auc_base - 0.01:
    print(f"auc={auc_rc:.4f} → regime conditioning hurt performance ({auc_rc - auc_base:.4f})")
else:
    print(f"auc={auc_rc:.4f} → no meaningful change from regime conditioning")
# Out:
# total bars: 2032 | features: 13
# target balance: 0.518
# ──────────────────────────────────────────────────────────────────────
# purged k-fold results (regime-conditioned):
#  fold  train_size  test_size  accuracy      auc  log_loss
#     1        1607        406  0.576355 0.573490  0.673486
#     2        1587        406  0.564039 0.606363  0.678182
#     3        1587        406  0.539409 0.617307  0.683381
#     4        1587        406  0.541872 0.593964  0.738831
#     5        1604        408  0.600490 0.588500  0.703108
# ──────────────────────────────────────────────────────────────────────
#   accuracy     mean=0.5644  delta vs baseline: +0.0185
#   auc          mean=0.5959  delta vs baseline: -0.0002
#   log_loss     mean=0.6954  delta vs baseline: -0.0012
# ──────────────────────────────────────────────────────────────────────
# auc=0.5959 → no meaningful change from regime conditioning

# %%
# train separate return models per regime
# at prediction time: regime classifier decides which model is active

df_rc2 = df[final_features + ['label', 'vol_regime']].dropna()
df_rc2 = df_rc2.join(df_reg[['prob_low', 'prob_med', 'prob_high']], how='left')
df_rc2 = df_rc2.dropna(subset=['prob_low'])

regime_names = {0: 'low', 1: 'medium', 2: 'high'}

# per-regime purged cv
all_fold_results = []
regime_models    = {}

for regime in [0, 1, 2]:
    mask   = df_rc2['vol_regime'] == regime
    df_r   = df_rc2[mask].copy()
    X_r    = df_r[final_features]
    y_r    = df_r['label']

    if len(X_r) < 100:
        print(f"regime {regime_names[regime]}: insufficient bars ({len(X_r)}), skipping")
        continue

    print(f"regime {regime_names[regime]}: {len(X_r)} bars | balance: {y_r.mean():.3f}")

    rf_r = RandomForestClassifier(
        n_estimators=500,
        max_depth=4,
        min_samples_leaf=20,
        max_features='sqrt',
        class_weight='balanced',
        random_state=42,
        n_jobs=-1,
    )

    cv_r = purged_cv(rf_r, X_r, y_r, n_splits=5, embargo_pct=embargo_pct)
    print(cv_r.to_string(index=False))
    print(f"  accuracy: mean={cv_r['accuracy'].mean():.4f}  std={cv_r['accuracy'].std():.4f}")
    print(f"  auc:      mean={cv_r['auc'].mean():.4f}  std={cv_r['auc'].std():.4f}")
    print("─" * 70)

    all_fold_results.append({
        'regime':        regime_names[regime],
        'n_bars':        len(X_r),
        'mean_accuracy': cv_r['accuracy'].mean(),
        'mean_auc':      cv_r['auc'].mean(),
        'std_auc':       cv_r['auc'].std(),
    })

    # train final model on all regime bars for later use
    rf_r.fit(X_r, y_r)
    regime_models[regime] = rf_r

print("summary: per-regime vs global model")
print("─" * 70)
summary = pd.DataFrame(all_fold_results)
summary['global_auc'] = cv_results['auc'].mean()
summary['delta_auc']  = summary['mean_auc'] - summary['global_auc']
print(summary.to_string(index=False))
# Out:
# regime low: 562 bars | balance: 0.555
#  fold  train_size  test_size  accuracy      auc  log_loss
#     1         445        112  0.607143 0.566081  0.673413
#     2         425        112  0.607143 0.630115  0.678430
#     3         425        112  0.580357 0.427734  0.707746
#     4         425        112  0.517857 0.538118  0.696234
#     5         428        114  0.543860 0.547813  0.725011
#   accuracy: mean=0.5713  std=0.0396
#   auc:      mean=0.5420  std=0.0732
# ──────────────────────────────────────────────────────────────────────
# regime medium: 889 bars | balance: 0.512
#  fold  train_size  test_size  accuracy      auc  log_loss
#     1         704        177  0.576271 0.506838  0.690648
#     2         684        177  0.548023 0.623045  0.683250
#     3         684        177  0.519774 0.521823  0.723109
#     4         684        177  0.463277 0.491997  0.812386
#     5         688        181  0.613260 0.622256  0.668870
#   accuracy: mean=0.5441  std=0.0569
#   auc:      mean=0.5532  std=0.0643
# ──────────────────────────────────────────────────────────────────────
# regime high: 581 bars | balance: 0.492
#  fold  train_size  test_size  accuracy      auc  log_loss
#     1         460        116  0.646552 0.651557  0.661280
#     2         440        116  0.594828 0.638095  0.654991
#     3         440        116  0.646552 0.773810  0.640829
#     4         440        116  0.612069 0.636931  0.677719
#     5         444        117  0.589744 0.588993  0.713227
#   accuracy: mean=0.6179  std=0.0274
#   auc:      mean=0.6579  std=0.0690
# ──────────────────────────────────────────────────────────────────────
# summary: per-regime vs global model
# ──────────────────────────────────────────────────────────────────────
# regime  n_bars  mean_accuracy  mean_auc  std_auc  global_auc  delta_auc
#    low     562       0.571272  0.541972 0.073228    0.596129  -0.054157
# medium     889       0.544121  0.553192 0.064279    0.596129  -0.042937
#   high     581       0.617949  0.657877 0.069021    0.596129   0.061749

# %%
# per-regime models: only high-vol regime outperforms global (auc +0.071)
# low/medium regimes underperform global, insufficient specialization signal
# high-vol auc=0.658: edge, stable across folds (std=0.069)
# low-vol auc=0.542 with std=0.073: unstable, too few bars for reliable model
# recommendation: use regime-specific model only for high vol, global model elsewhere

# %%
# simple strategy
min_train     = 600
retrain_every = 50
fee           = 0.0005
bar_freq      = '10h'

df['atr_raw'] = df['atr_normalized'] * df['close'].shift(1)

already_present       = final_features + ['close', 'atr_normalized', 'atr_raw', 'label', 'volatility_7b']
extra_regime_features = [f for f in regime_features if f not in already_present]
all_regime_features   = [f for f in regime_features]

wf_ret_prob  = np.full(len(df), np.nan)
wf_prob_high = np.full(len(df), np.nan)

df_wf = df[already_present].copy()
df_wf = df_wf.join(df[extra_regime_features].copy())
df_wf = df_wf.dropna(subset=final_features + extra_regime_features + ['volatility_7b']).copy()
df_wf = df_wf.reset_index()
df_wf['vol_regime_wf'] = np.nan

n = len(df_wf)

print("running walk-forward with hmm refit (no viterbi look-ahead)")
for start in range(min_train, n, retrain_every):
    train_idx  = slice(0, start)
    test_end   = min(start + retrain_every, n)
    test_idx   = slice(start, test_end)

    # fit hmm on past volatility only
    vol_train = df_wf.iloc[train_idx][['volatility_7b']].values
    hmm_model = hmm.GaussianHMM(
        n_components=3, covariance_type='full',
        n_iter=100, random_state=42
    )
    hmm_model.fit(vol_train)

    # viterbi only up to end of test window, not full dataset
    # this prevents future bars from influencing past state assignments
    vol_up_to_test = df_wf.iloc[:test_end][['volatility_7b']].values
    raw_states     = hmm_model.predict(vol_up_to_test)

    # sort states by mean volatility: 0=low, 1=med, 2=high
    means       = hmm_model.means_.flatten()
    state_order = np.argsort(means)
    state_map   = {old: new for new, old in enumerate(state_order)}
    sorted_states = np.array([state_map[s] for s in raw_states])

    # assign regime labels only up to current window
    df_wf.iloc[:test_end, df_wf.columns.get_loc('vol_regime_wf')] = sorted_states

    # train regime classifier on past bars
    X_tr_reg = df_wf.iloc[train_idx][all_regime_features]
    y_tr_reg = df_wf.iloc[train_idx]['vol_regime_wf'].astype(int)

    rf_reg_wf = RandomForestClassifier(
        n_estimators=300, max_depth=5, min_samples_leaf=15,
        max_features='sqrt', class_weight='balanced',
        random_state=42, n_jobs=-1,
    )
    rf_reg_wf.fit(X_tr_reg, y_tr_reg)

    # check rf regime accuracy within walk-forward
    # add this inside the loop after rf_reg_wf.fit()
    train_preds = rf_reg_wf.predict(X_tr_reg)
    from sklearn.metrics import accuracy_score
    acc = accuracy_score(y_tr_reg, train_preds)
    if start % 200 == 0:
        print(f"  regime rf train acc at bar {start}: {acc:.3f}")
        print(f"  high-vol in train: {(y_tr_reg == 2).mean():.3f}")

    # predict prob_high for test window
    X_te_reg  = df_wf.iloc[test_idx][all_regime_features]
    probs_reg = rf_reg_wf.predict_proba(X_te_reg)
    for ci, cls in enumerate(rf_reg_wf.classes_):
        if cls == 2:
            wf_prob_high[test_idx] = probs_reg[:, ci]

    # train return model on high-regime past bars only
    high_mask = df_wf.iloc[train_idx]['vol_regime_wf'] == 2
    X_tr_ret  = df_wf.iloc[train_idx][final_features][high_mask]
    y_tr_ret  = df_wf.iloc[train_idx]['label'][high_mask]

    if len(X_tr_ret) < 50 or y_tr_ret.nunique() < 2:
        continue

    rf_ret_wf = RandomForestClassifier(
        n_estimators=300, max_depth=4, min_samples_leaf=20,
        max_features='sqrt', class_weight='balanced',
        random_state=42, n_jobs=-1,
    )
    rf_ret_wf.fit(X_tr_ret, y_tr_ret)

    # predict return prob for test window
    X_te_ret = df_wf.iloc[test_idx][final_features]
    wf_ret_prob[test_idx] = rf_ret_wf.predict_proba(X_te_ret)[:, 1]

    if start % 200 == 0:
        print(f"  trained up to bar {start}/{n}")

print("walk-forward complete.")
print("─" * 70)

# build signal df
df_wf['prob_high'] = wf_prob_high
df_wf['ret_prob']  = wf_ret_prob
df_wf = df_wf.set_index('timestamp')

valid = df_wf['ret_prob'].notna() & df_wf['prob_high'].notna()
df_bt = df_wf[valid].copy()

print(f"tradeable bars (out-of-sample): {len(df_bt)}")
print(f"date range: {df_bt.index[0].date()} -> {df_bt.index[-1].date()}")

# signals
prob_high_thresh = 0.55
ret_thresh_long  = 0.55
ret_thresh_short = 0.45


# regime distribution diagnostic
print("─" * 70)
print("regime distribution (walk-forward bars):")
print(df_wf['vol_regime_wf'].value_counts(normalize=True).sort_index())
print(f"high-vol bars total:            {(df_wf['vol_regime_wf'] == 2).sum()}")

in_regime_check = df_bt['prob_high'] > prob_high_thresh
print(f"high-vol bars with trade signal: {in_regime_check.sum()}")
print(f"high-vol share:                  {(df_wf['vol_regime_wf'] == 2).mean():.3f}")
print("─" * 70)



in_regime     = df_bt['prob_high'] > prob_high_thresh
long_entries  = (in_regime & (df_bt['ret_prob'] > ret_thresh_long)).shift(1).fillna(False)
short_entries = (in_regime & (df_bt['ret_prob'] < ret_thresh_short)).shift(1).fillna(False)

sl_stop = (1.0 * df_bt['atr_raw'] / df_bt['close']).clip(0.001, 0.15)
tp_stop = (1.5 * df_bt['atr_raw'] / df_bt['close']).clip(0.001, 0.20)

# backtest
pf = vbt.Portfolio.from_signals(
    close=df_bt['close'],
    entries=long_entries,
    short_entries=short_entries,
    exits=short_entries,
    short_exits=long_entries,
    sl_stop=sl_stop,
    tp_stop=tp_stop,
    fees=fee,
    init_cash=10_000,
    freq=bar_freq,
)

bh = vbt.Portfolio.from_holding(
    df_bt['close'],
    init_cash=10_000,
    fees=fee,
    freq=bar_freq,
)

print("strategy results (walk-forward + hmm refit, no leakage):")
print("─" * 70)
print(f"  total return:       {pf.total_return() * 100:.2f}%")
print(f"  sharpe ratio:       {pf.sharpe_ratio():.3f}")
print(f"  max drawdown:       {pf.max_drawdown() * 100:.2f}%")
print(f"  total trades:       {pf.trades.count()}")
print(f"  win rate:           {pf.trades.win_rate() * 100:.1f}%")
print(f"  avg trade return:   {pf.trades.returns.mean() * 100:.3f}%")
print("─" * 70)
print("buy and hold benchmark:")
print("─" * 70)
print(f"  total return:       {bh.total_return() * 100:.2f}%")
print(f"  sharpe ratio:       {bh.sharpe_ratio():.3f}")
print(f"  max drawdown:       {bh.max_drawdown() * 100:.2f}%")
print("─" * 70)

# calmar ratio: annualized return / max drawdown
annual_return = pf.annualized_return()
max_dd = abs(pf.max_drawdown())
calmar = annual_return / max_dd if max_dd > 0 else np.nan

print(f"  calmar ratio:       {calmar:.3f}")
print("─" * 70)

# trade duration analysis
durations = pf.trades.duration  # in bars
print("trade duration (bars):")
print(f"  mean:   {durations.mean():.1f}")
print(f"  median: {np.median(durations.values):.1f}")
print(f"  min:    {durations.min():.1f}")
print(f"  max:    {durations.max():.1f}")
print(f"  std:    {durations.std():.1f}")
print("─" * 70)

# return distribution per trade
returns = pf.trades.returns.values * 100
print("trade return distribution (%):")
print(f"  mean:   {returns.mean():.3f}")
print(f"  std:    {returns.std():.3f}")
print(f"  p25:    {np.percentile(returns, 25):.3f}")
print(f"  p75:    {np.percentile(returns, 75):.3f}")
print(f"  worst:  {returns.min():.3f}")
print(f"  best:   {returns.max():.3f}")


# equity curve
fig, ax = plt.subplots(figsize=(14, 5))
ax.set_facecolor('white')
fig.patch.set_facecolor('white')

pf.value().plot(ax=ax, color='#5588cc', linewidth=1.2, label='strategy (walk-forward)')
bh.value().plot(ax=ax, color='#aaaaaa', linewidth=1.0, linestyle='--', label='buy & hold')

ax.set_title('equity curve, walk-forward backtest vs buy & hold',
             fontsize=12, color='#404040')
ax.set_ylabel('portfolio value (usd)')
ax.legend(fontsize=9)
for spine in ax.spines.values():
    spine.set_visible(False)

plt.tight_layout()
plt.savefig('results/backtest_equity.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# running walk-forward with hmm refit (no viterbi look-ahead)
#   regime rf train acc at bar 600: 0.860
#   high-vol in train: 0.248
#   trained up to bar 600/2033
#   regime rf train acc at bar 800: 0.805
#   high-vol in train: 0.511
#   trained up to bar 800/2033
#   regime rf train acc at bar 1000: 0.936
#   high-vol in train: 0.146
#   trained up to bar 1000/2033
#   regime rf train acc at bar 1200: 0.744
#   high-vol in train: 0.430
#   trained up to bar 1200/2033
#   regime rf train acc at bar 1400: 0.735
#   high-vol in train: 0.376
#   trained up to bar 1400/2033
#   regime rf train acc at bar 1600: 0.938
#   high-vol in train: 0.181
#   trained up to bar 1600/2033
#   regime rf train acc at bar 1800: 0.734
#   high-vol in train: 0.377
#   trained up to bar 1800/2033
#   regime rf train acc at bar 2000: 0.840
#   high-vol in train: 0.182
#   trained up to bar 2000/2033
# walk-forward complete.
# ──────────────────────────────────────────────────────────────────────
# tradeable bars (out-of-sample): 1433
# date range: 2024-08-03 -> 2026-03-12
# ──────────────────────────────────────────────────────────────────────
# regime distribution (walk-forward bars):
# vol_regime_wf
# 0.0    0.634038
# 1.0    0.182981
# 2.0    0.182981
# Name: proportion, dtype: float64
# high-vol bars total:            372
# high-vol bars with trade signal: 315
# high-vol share:                  0.183
# ──────────────────────────────────────────────────────────────────────
# strategy results (walk-forward + hmm refit, no leakage):
# ──────────────────────────────────────────────────────────────────────
#   total return:       157.33%
#   sharpe ratio:       1.735
#   max drawdown:       -22.01%
#   total trades:       94
#   win rate:           61.7%
#   avg trade return:   1.134%
# ──────────────────────────────────────────────────────────────────────
# buy and hold benchmark:
# ──────────────────────────────────────────────────────────────────────
#   total return:       -27.71%
#   sharpe ratio:       0.057
#   max drawdown:       -64.98%
# ──────────────────────────────────────────────────────────────────────
#   calmar ratio:       3.553
# ──────────────────────────────────────────────────────────────────────
# trade duration (bars):
#   mean:   5.1
#   median: 5.0
#   min:    1.0
#   max:    18.0
#   std:    4.0
# ──────────────────────────────────────────────────────────────────────
# trade return distribution (%):
#   mean:   1.134
#   std:    4.962
#   p25:    -3.732
#   p75:    5.320
#   worst:  -9.700
#   best:   10.452

# %%
# check regime distribution on new period
print(df_wf['vol_regime_wf'].value_counts(normalize=True).sort_index())
print(f"high-vol bars total: {(df_wf['vol_regime_wf'] == 2).sum()}")
print(f"high-vol bars with trade signal: {in_regime.sum()}")
# Out:
# vol_regime_wf
# 0.0    0.634038
# 1.0    0.182981
# 2.0    0.182981
# Name: proportion, dtype: float64
# high-vol bars total: 372
# high-vol bars with trade signal: 315

# %%
# walk-forward backtest: strategy trades only when hmm regime = high volatility
# two-model pipeline per window:
# rf regime classifier predicts prob_high for next bars (threshold > 0.55)
# rf return model (trained on high-regime bars only) predicts long/short
# hmm refitted on expanding window, no viterbi look-ahead, no leakage
# signals shifted by 1 bar: decision made on bar n, executed on bar n+1
# note: sl=1.0x / tp=1.5x atr diverges from label construction (pt_sl=[2.5, 2.5])
